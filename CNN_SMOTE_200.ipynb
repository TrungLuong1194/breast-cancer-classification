# %% [markdown]
# # **Connect to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/Colab\ Notebooks/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# # **Preprocessing the dataset**
#
# - Load the data from Google Drive.
# - In Google Drive, have 3 directories: train_data - valid_data - test_data.
# - In each folder, data is stored in h5py format.
# - Standardization (z-score).

# %%
import numpy as np
import h5py

# %%
def preprocessing_dataset(num_file, filename_prefix):
    X = []
    y = []

    # Load the data from h5py
    for i in range(1, num_file):
        
        filename = filename_prefix + str(i) + '.hdf5'
        print('Loading batch ' + str(i) + ' ...')

        with h5py.File(filename, 'r') as f:
            for j in f['X'][:]:
                X.append(j)

            for j in f['y'][:]:
                y.append(j)

    # Convert to numpy array
    X = np.array(X)
    y = np.array(y)

    # Calculate the mean of each channel
    mean_0 = X[:, 0, :, :].mean()
    mean_1 = X[:, 1, :, :].mean()
    mean_2 = X[:, 2, :, :].mean()

    # Calculate the standard deviation of each channel
    std_0 = X[:, 0, :, :].std()
    std_1 = X[:, 1, :, :].std()
    std_2 = X[:, 2, :, :].std()

    # Standardization
    X[:, 0, :, :] = (X[:, 0, :, :] - mean_0) / std_0
    X[:, 1, :, :] = (X[:, 1, :, :] - mean_1) / std_1
    X[:, 2, :, :] = (X[:, 2, :, :] - mean_2) / std_2

    return X, y

# %% [markdown]
# **Configure the dataset**

# %%
train_num_file = 10
train_filename_prefix = 'train_data/X_train_'

valid_num_file = 4
valid_filename_prefix = 'valid_data/X_valid_'

test_num_file = 4
test_filename_prefix = 'test_data/X_test_'

# %% [markdown]
# ### **Load the training set**

# %%
X_train, y_train = preprocessing_dataset(train_num_file, train_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...
# Loading batch 4 ...
# Loading batch 5 ...
# Loading batch 6 ...
# Loading batch 7 ...
# Loading batch 8 ...
# Loading batch 9 ...

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (165133, 3, 50, 50)
# (165133,)

# %% [markdown]
# ### **Load the validation set**

# %%
X_valid, y_valid = preprocessing_dataset(valid_num_file, valid_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...

# %%
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (55044, 3, 50, 50)
# (55044,)

# %% [markdown]
# ### **Load the test set**

# %%
X_test, y_test = preprocessing_dataset(test_num_file, test_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (55045, 3, 50, 50)
# (55045,)

# %% [markdown]
# # **Building Model Convolution Neural Network**

# %%
import math
import time
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import torch
import torch.nn as nn
from torch import optim
from imblearn.over_sampling import SMOTE
import collections

from warnings import simplefilter, filterwarnings
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %% [markdown]
# ### **Parameters of the model**

# %%
EPOCHS = 80
BATCH_SIZE = 128
LR = 1e-6

# %% [markdown]
# ### **Defining the Model**

# %% [markdown]
# **Model description:**
#
# - Input model is RGB image data (3 color channels, 50 pixels height, 50 pixels width)
# - Transform input image to multi-dimensional matrix with size 3 - 50 - 50.
#
#
# **Activation function**
#
# - The ReLU is the most used activation function in the world right now. Since, it is used in almost all the convolutional neural networks or deep learning.
# - Computationally efficient—allows the network to converge very quickly.
# - Non-linear—although it looks like a linear function, ReLU has a derivative function and allows for backpropagation.
#
# ![ReLU-activation-function.png](data:image/png;base64,...)
#
# **Avoid overfitting**
#
# To avoid overfitting in neural networks, use two methods of Dropout and Batch normalization.
# - **Dropout**: is one of the most commonly used and the most powerful regularization techniques used in deep learning. Dropout is applied to intermediate layers of the model during the training time. Let's look at an example of how dropout is applied on a linear layer's output that generates 10 values:
#
#   + The figure shows what happens when dropout is applied to the linear layer output with a threshold value of 0.2. It randomly masks or zeros 20% of data, so that the model will not be dependent on a particular set of weights or patterns, thus overfitting.
#
# ![a.png](data:image/png;base64,...)
#
# - **Batch normalization**: (also known as batch norm) is a method used to make artificial neural networks faster and more stable through normalization of the input layer by re-centering and re-scaling. To increase the stability of a neural network, batch normalization normalizes the output of a previous activation layer by subtracting the batch mean and dividing by the batch standard deviation.

# %%
class CNN(nn.Module):
  
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=2)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=2)
        self.conv5 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=2)

        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(128)
        self.bn4 = nn.BatchNorm2d(256)
        self.bn5 = nn.BatchNorm2d(512)

        self.mp = nn.MaxPool2d(kernel_size=2)
        self.relu = nn.ReLU()
        self.do = nn.Dropout()

        self.fc1 = nn.Linear(4608, 1024)
        self.fc2 = nn.Linear(1024, 256)
        self.fc3 = nn.Linear(256, 64)
        self.fc4 = nn.Linear(64, 16)
        self.fc5 = nn.Linear(16, 2)

    def forward(self, x):
        x = self.mp(self.relu(self.bn1(self.conv1(x))))
        x = self.mp(self.relu(self.bn2(self.conv2(x))))
        x = self.mp(self.relu(self.bn3(self.conv3(x))))
        x = self.mp(self.relu(self.bn4(self.conv4(x))))
        x = self.do(self.mp(self.relu(self.bn5(self.conv5(x)))))

        x = x.view(x.shape[0], -1)

        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.relu(self.fc4(x))
        out = self.fc5(x)

        return out

# %%
model = CNN()
print(model)
# Out:
# CNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (mp): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (do): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=4608, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=16, bias=True)
#   (fc5): Linear(in_features=16, out_features=2, bias=True)
# )

# %% [markdown]
# **Calculate the number of trainable parameters (weights and biases)**

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 6,570,098 trainable parameters

# %% [markdown]
# **Optimization Algorithm**
#
# - Steps to optimization
#
#   + Pass a batch of data through your model.
#   + Calculate the loss of your batch by comparing your model's predictions against the actual labels.
#   + Calculate the gradient of each of your parameters with respect to the loss.
#   + Update each of your parameters by subtracting their gradient multiplied by a small learning rate parameter.

# %%
optimizer = optim.Adam(model.parameters(), lr=LR)

# %% [markdown]
# **Loss Fuction**
#
# - **Cross-entropy** can be used to define a loss function in machine learning and optimization.

# %%
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# **Calculate the accuracy**
# - This takes the index of the highest value for your prediction and compares it against the actual class label. Then divide how many our model got correct by the amount in the batch to calculate accuracy across the batch.

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %% [markdown]
# **Create mini-batch**

# %%
def next_batch(X, y, batch_size):
    # Mini-batch
    for i in np.arange(0, X.shape[0], batch_size):
        yield X[i:i + batch_size], y[i:i + batch_size]

# %% [markdown]
# **Transform the model and data to GPU**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)
loss_fn = loss_fn.to(device)

# %% [markdown]
# ### **Training the Model**

# %% [markdown]
# **Define Traning step**
# - Put the model into train mode: **model.train()**
# - Iterate over batches of data.
# - Transform the batch to GPU mode.
# - Clear the gradients calculated from the last batch.
# - Impliment model for batch of images: x, get predictions, y_pred.
# - Calculate the loss between prediction labels and the actual labels.
# - Calculate the accuracy between prediction labels and the actual labels.
# - Calculate the gradients of each parameter.
# - Update the parameters by taking optimizer step.
# - Return the loss and the accuracy of epoch.

# %%
def train(model, X, y, optimizer, loss_fn, device, batch_size):
    epoch_loss = 0
    epoch_acc = 0
    
    # Impliment train mode
    model.train()
    
    for (batchX, batchY) in next_batch(X, y, batch_size):
        # SMOTE
        x_tmp = batchX.reshape(batchX.shape[0], 3 * 50 * 50)
        y_tmp = batchY

        count = collections.Counter(y_tmp)

        x_smote, y_smote = SMOTE(sampling_strategy={0: count[0], 1: count[0] * 2}, k_neighbors=3).fit_resample(x_tmp, y_tmp)
        x_smote = x_smote.reshape(x_smote.shape[0], 3, 50, 50)

        # Create tensor
        x = torch.from_numpy(x_smote).to(device)
        y = torch.from_numpy(y_smote).to(device)
        
        # Clear the gradients calculated from the last batch
        optimizer.zero_grad()
                
        y_pred = model(x)

        loss = loss_fn(y_pred, y)
        acc = calculate_accuracy(y_pred, y)
        
        # Calculate the gradients of each parameter
        loss.backward()
        
        # Update the parameters
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    num_of_batchs = math.ceil(len(X) / batch_size)
    return epoch_loss / num_of_batchs, epoch_acc / num_of_batchs

# %% [markdown]
# **Define Evaluation step**
#
# - Similar the training step. The differences are:
#   + Put the model into evalution mode: **model.eval()**
#   + Don't calculate the gradients of each parameter.
#   + Don't update the parameters by taking optimizer step.
#
# - **torch.no_grad()** ensures that gradients are not calculated for whatever is inside the with block. As our model will not have to calculate gradients it will be faster and use less memory.

# %%
def evaluate(model, X, y, loss_fn, device, batch_size):
    epoch_loss = 0
    epoch_acc = 0
    
    # Impliment evaluation mode
    model.eval()
    
    with torch.no_grad():
        for (batchX, batchY) in next_batch(X, y, batch_size):
            x = torch.from_numpy(batchX).to(device)
            y = torch.from_numpy(batchY).to(device)

            y_pred = model(x)

            loss = loss_fn(y_pred, y)
            acc = calculate_accuracy(y_pred, y)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    num_of_batchs = math.ceil(len(X) / batch_size)
    return epoch_loss / num_of_batchs, epoch_acc / num_of_batchs

# %% [markdown]
# **Calculate the time need to run each epoch**

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %% [markdown]
# **Training the Model**
# - Iterate over epochs.
# - In each epochs:
#   - Training the Model with training set.
#   - Evaluate the Model with validation set.
#   - Check the best validation loss and save the model parameters
#   - Print the result metrics: Loss and Accuracy.

# %%
best_valid_loss = float('inf')
train_loss_list = list()
valid_loss_list = list()

for epoch in range(EPOCHS):
    start_time = time.monotonic()

    train_loss, train_acc = train(model, X_train, y_train, optimizer, loss_fn, device, batch_size=BATCH_SIZE)
    valid_loss, valid_acc = evaluate(model, X_valid, y_valid, loss_fn, device, batch_size=BATCH_SIZE)

    train_loss_list.append(train_loss)
    valid_loss_list.append(valid_loss)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'smote_v2.pt')
    
    end_time = time.monotonic()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')
# Out:
# Epoch: 01 | Epoch Time: 1m 33s
# 	Train Loss: 0.434 | Train Acc: 83.83%
# 	 Val. Loss: 0.464 |  Val. Acc: 79.73%
# Epoch: 02 | Epoch Time: 1m 33s
# 	Train Loss: 0.279 | Train Acc: 88.56%
# 	 Val. Loss: 0.430 |  Val. Acc: 81.58%
# Epoch: 03 | Epoch Time: 1m 33s
# 	Train Loss: 0.261 | Train Acc: 89.26%
# 	 Val. Loss: 0.418 |  Val. Acc: 82.12%
# Epoch: 04 | Epoch Time: 1m 33s
# 	Train Loss: 0.252 | Train Acc: 89.63%
# 	 Val. Loss: 0.409 |  Val. Acc: 82.49%
# Epoch: 05 | Epoch Time: 1m 33s
# 	Train Loss: 0.246 | Train Acc: 89.91%
# 	 Val. Loss: 0.398 |  Val. Acc: 82.97%
# Epoch: 06 | Epoch Time: 1m 33s
# 	Train Loss: 0.240 | Train Acc: 90.19%
# 	 Val. Loss: 0.392 |  Val. Acc: 83.32%
# Epoch: 07 | Epoch Time: 1m 33s
# 	Train Loss: 0.236 | Train Acc: 90.38%
# 	 Val. Loss: 0.393 |  Val. Acc: 83.28%
# Epoch: 08 | Epoch Time: 1m 33s
# 	Train Loss: 0.234 | Train Acc: 90.51%
# 	 Val. Loss: 0.381 |  Val. Acc: 83.89%
# Epoch: 09 | Epoch Time: 1m 33s
# 	Train Loss: 0.231 | Train Acc: 90.66%
# 	 Val. Loss: 0.382 |  Val. Acc: 83.84%
# Epoch: 10 | Epoch Time: 1m 33s
# 	Train Loss: 0.229 | Train Acc: 90.78%
# 	 Val. Loss: 0.380 |  Val. Acc: 83.92%
# Epoch: 11 | Epoch Time: 1m 33s
# 	Train Loss: 0.227 | Train Acc: 90.85%
# 	 Val. Loss: 0.379 |  Val. Acc: 83.99%
# Epoch: 12 | Epoch Time: 1m 33s
# 	Train Loss: 0.225 | Train Acc: 90.86%
# 	 Val. Loss: 0.371 |  Val. Acc: 84.35%
# Epoch: 13 | Epoch Time: 1m 33s
# 	Train Loss: 0.225 | Train Acc: 90.93%
# 	 Val. Loss: 0.372 |  Val. Acc: 84.30%
# Epoch: 14 | Epoch Time: 1m 33s
# 	Train Loss: 0.222 | Train Acc: 91.02%
# 	 Val. Loss: 0.378 |  Val. Acc: 84.08%
# Epoch: 15 | Epoch Time: 1m 33s
# 	Train Loss: 0.221 | Train Acc: 91.12%
# 	 Val. Loss: 0.373 |  Val. Acc: 84.28%
# Epoch: 16 | Epoch Time: 1m 33s
# 	Train Loss: 0.220 | Train Acc: 91.17%
# 	 Val. Loss: 0.366 |  Val. Acc: 84.55%
# Epoch: 17 | Epoch Time: 1m 33s
# 	Train Loss: 0.218 | Train Acc: 91.21%
# 	 Val. Loss: 0.370 |  Val. Acc: 84.40%
# Epoch: 18 | Epoch Time: 1m 33s
# 	Train Loss: 0.217 | Train Acc: 91.28%
# 	 Val. Loss: 0.370 |  Val. Acc: 84.47%
# Epoch: 19 | Epoch Time: 1m 33s
# 	Train Loss: 0.216 | Train Acc: 91.35%
# 	 Val. Loss: 0.371 |  Val. Acc: 84.41%
# Epoch: 20 | Epoch Time: 1m 32s
# 	Train Loss: 0.215 | Train Acc: 91.35%
# 	 Val. Loss: 0.367 |  Val. Acc: 84.53%
# Epoch: 21 | Epoch Time: 1m 33s
# 	Train Loss: 0.214 | Train Acc: 91.41%
# 	 Val. Loss: 0.363 |  Val. Acc: 84.77%
# Epoch: 22 | Epoch Time: 1m 32s
# 	Train Loss: 0.212 | Train Acc: 91.49%
# 	 Val. Loss: 0.369 |  Val. Acc: 84.47%
# Epoch: 23 | Epoch Time: 1m 33s
# 	Train Loss: 0.211 | Train Acc: 91.54%
# 	 Val. Loss: 0.369 |  Val. Acc: 84.49%
# Epoch: 24 | Epoch Time: 1m 33s
# 	Train Loss: 0.211 | Train Acc: 91.50%
# 	 Val. Loss: 0.365 |  Val. Acc: 84.66%
# Epoch: 25 | Epoch Time: 1m 33s
# 	Train Loss: 0.210 | Train Acc: 91.57%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.14%
# Epoch: 26 | Epoch Time: 1m 32s
# 	Train Loss: 0.208 | Train Acc: 91.65%
# 	 Val. Loss: 0.359 |  Val. Acc: 84.88%
# Epoch: 27 | Epoch Time: 1m 33s
# 	Train Loss: 0.207 | Train Acc: 91.72%
# 	 Val. Loss: 0.360 |  Val. Acc: 84.86%
# Epoch: 28 | Epoch Time: 1m 32s
# 	Train Loss: 0.207 | Train Acc: 91.74%
# 	 Val. Loss: 0.363 |  Val. Acc: 84.78%
# Epoch: 29 | Epoch Time: 1m 32s
# 	Train Loss: 0.206 | Train Acc: 91.72%
# 	 Val. Loss: 0.360 |  Val. Acc: 84.87%
# Epoch: 30 | Epoch Time: 1m 34s
# 	Train Loss: 0.205 | Train Acc: 91.84%
# 	 Val. Loss: 0.360 |  Val. Acc: 84.98%
# Epoch: 31 | Epoch Time: 1m 33s
# 	Train Loss: 0.204 | Train Acc: 91.78%
# 	 Val. Loss: 0.360 |  Val. Acc: 84.94%
# Epoch: 32 | Epoch Time: 1m 33s
# 	Train Loss: 0.204 | Train Acc: 91.82%
# 	 Val. Loss: 0.358 |  Val. Acc: 85.03%
# Epoch: 33 | Epoch Time: 1m 33s
# 	Train Loss: 0.202 | Train Acc: 91.93%
# 	 Val. Loss: 0.361 |  Val. Acc: 84.91%
# Epoch: 34 | Epoch Time: 1m 33s
# 	Train Loss: 0.202 | Train Acc: 91.91%
# 	 Val. Loss: 0.360 |  Val. Acc: 84.96%
# Epoch: 35 | Epoch Time: 1m 33s
# 	Train Loss: 0.201 | Train Acc: 91.95%
# 	 Val. Loss: 0.358 |  Val. Acc: 85.06%
# Epoch: 36 | Epoch Time: 1m 33s
# 	Train Loss: 0.200 | Train Acc: 92.00%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.15%
# Epoch: 37 | Epoch Time: 1m 33s
# 	Train Loss: 0.200 | Train Acc: 92.01%
# 	 Val. Loss: 0.359 |  Val. Acc: 84.99%
# Epoch: 38 | Epoch Time: 1m 34s
# 	Train Loss: 0.198 | Train Acc: 92.11%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.13%
# Epoch: 39 | Epoch Time: 1m 33s
# 	Train Loss: 0.198 | Train Acc: 92.08%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.08%
# Epoch: 40 | Epoch Time: 1m 33s
# 	Train Loss: 0.197 | Train Acc: 92.14%
# 	 Val. Loss: 0.357 |  Val. Acc: 85.11%
# Epoch: 41 | Epoch Time: 1m 33s
# 	Train Loss: 0.196 | Train Acc: 92.17%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.18%
# Epoch: 42 | Epoch Time: 1m 33s
# 	Train Loss: 0.196 | Train Acc: 92.12%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.10%
# Epoch: 43 | Epoch Time: 1m 33s
# 	Train Loss: 0.195 | Train Acc: 92.22%
# 	 Val. Loss: 0.358 |  Val. Acc: 85.01%
# Epoch: 44 | Epoch Time: 1m 33s
# 	Train Loss: 0.195 | Train Acc: 92.21%
# 	 Val. Loss: 0.357 |  Val. Acc: 85.07%
# Epoch: 45 | Epoch Time: 1m 33s
# 	Train Loss: 0.194 | Train Acc: 92.25%
# 	 Val. Loss: 0.359 |  Val. Acc: 84.97%
# Epoch: 46 | Epoch Time: 1m 33s
# 	Train Loss: 0.193 | Train Acc: 92.33%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.25%
# Epoch: 47 | Epoch Time: 1m 33s
# 	Train Loss: 0.193 | Train Acc: 92.33%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.38%
# Epoch: 48 | Epoch Time: 1m 33s
# 	Train Loss: 0.192 | Train Acc: 92.37%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.31%
# Epoch: 49 | Epoch Time: 1m 33s
# 	Train Loss: 0.191 | Train Acc: 92.39%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.23%
# Epoch: 50 | Epoch Time: 1m 33s
# 	Train Loss: 0.191 | Train Acc: 92.37%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.29%
# Epoch: 51 | Epoch Time: 1m 33s
# 	Train Loss: 0.190 | Train Acc: 92.47%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.19%
# Epoch: 52 | Epoch Time: 1m 33s
# 	Train Loss: 0.189 | Train Acc: 92.53%
# 	 Val. Loss: 0.350 |  Val. Acc: 85.43%
# Epoch: 53 | Epoch Time: 1m 33s
# 	Train Loss: 0.188 | Train Acc: 92.50%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.15%
# Epoch: 54 | Epoch Time: 1m 33s
# 	Train Loss: 0.188 | Train Acc: 92.48%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.35%
# Epoch: 55 | Epoch Time: 1m 33s
# 	Train Loss: 0.187 | Train Acc: 92.54%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.43%
# Epoch: 56 | Epoch Time: 1m 34s
# 	Train Loss: 0.186 | Train Acc: 92.62%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.54%
# Epoch: 57 | Epoch Time: 1m 33s
# 	Train Loss: 0.186 | Train Acc: 92.58%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.25%
# Epoch: 58 | Epoch Time: 1m 33s
# 	Train Loss: 0.185 | Train Acc: 92.67%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.52%
# Epoch: 59 | Epoch Time: 1m 33s
# 	Train Loss: 0.185 | Train Acc: 92.64%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.45%
# Epoch: 60 | Epoch Time: 1m 33s
# 	Train Loss: 0.184 | Train Acc: 92.66%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.24%
# Epoch: 61 | Epoch Time: 1m 33s
# 	Train Loss: 0.183 | Train Acc: 92.71%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.40%
# Epoch: 62 | Epoch Time: 1m 33s
# 	Train Loss: 0.183 | Train Acc: 92.69%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.22%
# Epoch: 63 | Epoch Time: 1m 33s
# 	Train Loss: 0.182 | Train Acc: 92.79%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.35%
# Epoch: 64 | Epoch Time: 1m 33s
# 	Train Loss: 0.182 | Train Acc: 92.74%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.34%
# Epoch: 65 | Epoch Time: 1m 33s
# 	Train Loss: 0.181 | Train Acc: 92.80%
# 	 Val. Loss: 0.357 |  Val. Acc: 85.25%
# Epoch: 66 | Epoch Time: 1m 33s
# 	Train Loss: 0.180 | Train Acc: 92.89%
# 	 Val. Loss: 0.350 |  Val. Acc: 85.52%
# Epoch: 67 | Epoch Time: 1m 33s
# 	Train Loss: 0.180 | Train Acc: 92.86%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.45%
# Epoch: 68 | Epoch Time: 1m 33s
# 	Train Loss: 0.180 | Train Acc: 92.87%
# 	 Val. Loss: 0.348 |  Val. Acc: 85.51%
# Epoch: 69 | Epoch Time: 1m 33s
# 	Train Loss: 0.179 | Train Acc: 92.89%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.32%
# Epoch: 70 | Epoch Time: 1m 33s
# 	Train Loss: 0.177 | Train Acc: 93.00%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.31%
# Epoch: 71 | Epoch Time: 1m 33s
# 	Train Loss: 0.177 | Train Acc: 92.93%
# 	 Val. Loss: 0.344 |  Val. Acc: 85.82%
# Epoch: 72 | Epoch Time: 1m 33s
# 	Train Loss: 0.177 | Train Acc: 93.03%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.41%
# Epoch: 73 | Epoch Time: 1m 33s
# 	Train Loss: 0.176 | Train Acc: 93.02%
# 	 Val. Loss: 0.347 |  Val. Acc: 85.72%
# Epoch: 74 | Epoch Time: 1m 33s
# 	Train Loss: 0.176 | Train Acc: 93.07%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.47%
# Epoch: 75 | Epoch Time: 1m 33s
# 	Train Loss: 0.175 | Train Acc: 93.06%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.42%
# Epoch: 76 | Epoch Time: 1m 32s
# 	Train Loss: 0.174 | Train Acc: 93.09%
# 	 Val. Loss: 0.359 |  Val. Acc: 85.25%
# Epoch: 77 | Epoch Time: 1m 32s
# 	Train Loss: 0.173 | Train Acc: 93.15%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.64%
# Epoch: 78 | Epoch Time: 1m 33s
# 	Train Loss: 0.173 | Train Acc: 93.17%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.43%
# Epoch: 79 | Epoch Time: 1m 33s
# 	Train Loss: 0.172 | Train Acc: 93.17%
# 	 Val. Loss: 0.346 |  Val. Acc: 85.79%
# Epoch: 80 | Epoch Time: 1m 32s
# 	Train Loss: 0.172 | Train Acc: 93.19%
# 	 Val. Loss: 0.356 |  Val. Acc: 85.47%

# %% [markdown]
# **Load the parameters of the best model**

# %%
model.load_state_dict(torch.load('smote_v2.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### **Examining the Model**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, balanced_accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# **Visualizing loss of train set and valid set**

# %%
epoch_list = np.arange(1, EPOCHS + 1)

# %%
fig, ax = plt.subplots(figsize=(14,8))

ax.plot(epoch_list, train_loss_list, label='train loss')
ax.plot(epoch_list, valid_loss_list, label='validate loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')

ax.legend()
plt.show()

# %% [markdown]
# **Get the predictions**

# %%
def get_predictions(model, X, y, device, batch_size):
    
    model.eval()
    y_predict = []

    with torch.no_grad():
        for (batchX, batchY) in next_batch(X, y, batch_size):
            X = torch.from_numpy(batchX).to(device)

            y_tmp = model(X)
            top_pred = y_tmp.argmax(1, keepdim = True)

            for i in top_pred:
                y_predict.append(i.item())

    return np.array(y_predict)

# %%
y_predict = get_predictions(model, X_test, y_test, device, batch_size=BATCH_SIZE)

# %% [markdown]
# **Confusion matrix**

# %%
cm = confusion_matrix(y_test, y_predict)
print(cm)
# Out:
# [[34790  4638]
#  [ 2866 12751]]

# %%
pd_cm = pd.DataFrame(cm, index = ['negative', 'positive'], columns = ['negative', 'positive'])

# %%
plt.figure(figsize=(14,10))
ax = plt.axes()
sn.heatmap(pd_cm, annot=True, fmt='d', cmap='Blues')
ax.set_xlabel('Predict label')
ax.set_ylabel('True label')

plt.show()

# %% [markdown]
# **Quantifying the quality of predictions**

# %%
def show_metrics_scores(y_test, y_predict):
    print(f'Accuracy score\t\t: {accuracy_score(y_test, y_predict):.4f}\n')
    print(f'Balanced accuracy score\t: {balanced_accuracy_score(y_test, y_predict):.4f}\n')
    print(f'F1 score\t\t: {f1_score(y_test, y_predict):.4f}\n')
    print(f'Recall score\t\t: {recall_score(y_test, y_predict):.4f}')

# %%
show_metrics_scores(y_test, y_predict)
# Out:
# Accuracy score		: 0.8637
#
# Balanced accuracy score	: 0.8494
#
# F1 score		: 0.7726
#
# Recall score		: 0.8165
