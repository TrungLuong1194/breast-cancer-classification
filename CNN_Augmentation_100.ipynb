# %% [markdown]
# # **Data augementation with 100% of positive patches**

# %% [markdown]
# # **Connect to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/Colab\ Notebooks/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# # **Preprocessing the dataset**
#
# - Load the data from Google Drive.
# - In Google Drive, have 3 directories: train_data - valid_data - test_data.
# - In each folder, data is stored in h5py format.
# - Standardization (z-score).

# %%
import numpy as np
import h5py

# %%
def preprocessing_dataset(num_file, filename_prefix):
    X = []
    y = []

    # Load the data from h5py
    for i in range(1, num_file):
        
        filename = filename_prefix + str(i) + '.hdf5'
        print('Loading batch ' + str(i) + ' ...')

        with h5py.File(filename, 'r') as f:
            for j in f['X'][:]:
                X.append(j)

            for j in f['y'][:]:
                y.append(j)

    # Convert to numpy array
    X = np.array(X)
    y = np.array(y)

    # Calculate the mean of each channel
    mean_0 = X[:, 0, :, :].mean()
    mean_1 = X[:, 1, :, :].mean()
    mean_2 = X[:, 2, :, :].mean()

    # Calculate the standard deviation of each channel
    std_0 = X[:, 0, :, :].std()
    std_1 = X[:, 1, :, :].std()
    std_2 = X[:, 2, :, :].std()

    # Standardization
    X[:, 0, :, :] = (X[:, 0, :, :] - mean_0) / std_0
    X[:, 1, :, :] = (X[:, 1, :, :] - mean_1) / std_1
    X[:, 2, :, :] = (X[:, 2, :, :] - mean_2) / std_2

    return X, y

# %% [markdown]
# **Configure the dataset**

# %%
train_num_file = 12
train_filename_prefix = 'train_data/X_train_'

valid_num_file = 4
valid_filename_prefix = 'valid_data/X_valid_'

test_num_file = 4
test_filename_prefix = 'test_data/X_test_'

# %% [markdown]
# ### **Load the training set**

# %%
X_train, y_train = preprocessing_dataset(train_num_file, train_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...
# Loading batch 4 ...
# Loading batch 5 ...
# Loading batch 6 ...
# Loading batch 7 ...
# Loading batch 8 ...
# Loading batch 9 ...
# Loading batch 10 ...
# Loading batch 11 ...

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (212392, 3, 50, 50)
# (212392,)

# %% [markdown]
# ### **Load the validation set**

# %%
X_valid, y_valid = preprocessing_dataset(valid_num_file, valid_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...

# %%
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (55044, 3, 50, 50)
# (55044,)

# %% [markdown]
# ### **Load the test set**

# %%
X_test, y_test = preprocessing_dataset(test_num_file, test_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (55045, 3, 50, 50)
# (55045,)

# %% [markdown]
# # **Building Model Convolution Neural Network**

# %%
import math
import time
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import torch
import torch.nn as nn
from torch import optim

# %% [markdown]
# ### **Parameters of the model**

# %%
EPOCHS = 200
BATCH_SIZE = 256
LR = 1e-4

# %% [markdown]
# ### **Defining the Model**

# %% [markdown]
# **Model description:**
#
# - Input model is RGB image data (3 color channels, 50 pixels height, 50 pixels width)
# - Transform input image to multi-dimensional matrix with size 3 - 50 - 50.
#
#
# **Activation function**
#
# - The ReLU is the most used activation function in the world right now. Since, it is used in almost all the convolutional neural networks or deep learning.
# - Computationally efficient—allows the network to converge very quickly.
# - Non-linear—although it looks like a linear function, ReLU has a derivative function and allows for backpropagation.
#
# ![ReLU-activation-function.png](data:image/png;base64,...)
#
# **Avoid overfitting**
#
# To avoid overfitting in neural networks, use two methods of Dropout and Batch normalization.
# - **Dropout**: is one of the most commonly used and the most powerful regularization techniques used in deep learning. Dropout is applied to intermediate layers of the model during the training time. Let's look at an example of how dropout is applied on a linear layer's output that generates 10 values:
#
#   + The figure shows what happens when dropout is applied to the linear layer output with a threshold value of 0.2. It randomly masks or zeros 20% of data, so that the model will not be dependent on a particular set of weights or patterns, thus overfitting.
#
# ![a.png](data:image/png;base64,...)
#
# - **Batch normalization**: (also known as batch norm) is a method used to make artificial neural networks faster and more stable through normalization of the input layer by re-centering and re-scaling. To increase the stability of a neural network, batch normalization normalizes the output of a previous activation layer by subtracting the batch mean and dividing by the batch standard deviation.

# %%
class CNN(nn.Module):
  
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=2)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=2)
        self.conv5 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=2)

        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(128)
        self.bn4 = nn.BatchNorm2d(256)
        self.bn5 = nn.BatchNorm2d(512)

        self.mp = nn.MaxPool2d(kernel_size=2, padding=1)
        self.relu = nn.ReLU()
        self.do = nn.Dropout()

        self.fc1 = nn.Linear(12800, 4096)
        self.fc2 = nn.Linear(4096, 1024)
        self.fc3 = nn.Linear(1024, 256)
        self.fc4 = nn.Linear(256, 64)
        self.fc5 = nn.Linear(64, 16)
        self.fc6 = nn.Linear(16, 2)

    def forward(self, x):
        x = self.mp(self.relu(self.bn1(self.conv1(x))))
        x = self.mp(self.relu(self.bn2(self.conv2(x))))
        x = self.mp(self.relu(self.bn3(self.conv3(x))))
        x = self.mp(self.relu(self.bn4(self.conv4(x))))
        x = self.do(self.mp(self.relu(self.bn5(self.conv5(x)))))

        x = x.view(x.shape[0], -1)

        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.relu(self.fc4(x))
        out = self.fc5(x)

        return out

# %%
model = CNN()
print(model)
# Out:
# CNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (mp): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (do): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=12800, out_features=4096, bias=True)
#   (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=64, bias=True)
#   (fc5): Linear(in_features=64, out_features=16, bias=True)
#   (fc6): Linear(in_features=16, out_features=2, bias=True)
# )

# %% [markdown]
# **Calculate the number of trainable parameters (weights and biases)**

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 58,478,706 trainable parameters

# %% [markdown]
# **Optimization Algorithm**
#
# - Steps to optimization
#
#   + Pass a batch of data through your model.
#   + Calculate the loss of your batch by comparing your model's predictions against the actual labels.
#   + Calculate the gradient of each of your parameters with respect to the loss.
#   + Update each of your parameters by subtracting their gradient multiplied by a small learning rate parameter.

# %%
optimizer = optim.SGD(model.parameters(), lr=LR)

# %% [markdown]
# **Loss Fuction**
#
# - **Cross-entropy** can be used to define a loss function in machine learning and optimization.

# %%
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# **Calculate the accuracy**
# - This takes the index of the highest value for your prediction and compares it against the actual class label. Then divide how many our model got correct by the amount in the batch to calculate accuracy across the batch.

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %% [markdown]
# **Create mini-batch**

# %%
def next_batch(X, y, batch_size):
    # Mini-batch
    for i in np.arange(0, X.shape[0], batch_size):
        yield X[i:i + batch_size], y[i:i + batch_size]

# %% [markdown]
# **Transform the model and data to GPU**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)
loss_fn = loss_fn.to(device)

# %% [markdown]
# ### **Training the Model**

# %% [markdown]
# **Define Traning step**
# - Put the model into train mode: **model.train()**
# - Iterate over batches of data.
# - Transform the batch to GPU mode.
# - Clear the gradients calculated from the last batch.
# - Impliment model for batch of images: x, get predictions, y_pred.
# - Calculate the loss between prediction labels and the actual labels.
# - Calculate the accuracy between prediction labels and the actual labels.
# - Calculate the gradients of each parameter.
# - Update the parameters by taking optimizer step.
# - Return the loss and the accuracy of epoch.

# %%
def train(model, X, y, optimizer, loss_fn, device, batch_size):
    epoch_loss = 0
    epoch_acc = 0
    
    # Impliment train mode
    model.train()
    
    for (batchX, batchY) in next_batch(X, y, batch_size):
        x = torch.from_numpy(batchX).to(device)
        y = torch.from_numpy(batchY).to(device)
        
        # Clear the gradients calculated from the last batch
        optimizer.zero_grad()
                
        y_pred = model(x)

        loss = loss_fn(y_pred, y)
        acc = calculate_accuracy(y_pred, y)
        
        # Calculate the gradients of each parameter
        loss.backward()
        
        # Update the parameters
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    num_of_batchs = math.ceil(len(X) / batch_size)
    return epoch_loss / num_of_batchs, epoch_acc / num_of_batchs

# %% [markdown]
# **Define Evaluation step**
#
# - Similar the training step. The differences are:
#   + Put the model into evalution mode: **model.eval()**
#   + Don't calculate the gradients of each parameter.
#   + Don't update the parameters by taking optimizer step.
#
# - **torch.no_grad()** ensures that gradients are not calculated for whatever is inside the with block. As our model will not have to calculate gradients it will be faster and use less memory.

# %%
def evaluate(model, X, y, loss_fn, device, batch_size):
    epoch_loss = 0
    epoch_acc = 0
    
    # Impliment evaluation mode
    model.eval()
    
    with torch.no_grad():
        for (batchX, batchY) in next_batch(X, y, batch_size):
            x = torch.from_numpy(batchX).to(device)
            y = torch.from_numpy(batchY).to(device)

            y_pred = model(x)

            loss = loss_fn(y_pred, y)
            acc = calculate_accuracy(y_pred, y)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    num_of_batchs = math.ceil(len(X) / batch_size)
    return epoch_loss / num_of_batchs, epoch_acc / num_of_batchs

# %% [markdown]
# **Calculate the time need to run each epoch**

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %% [markdown]
# **Training the Model**
# - Iterate over epochs.
# - In each epochs:
#   - Training the Model with training set.
#   - Evaluate the Model with validation set.
#   - Check the best validation loss and save the model parameters
#   - Print the result metrics: Loss and Accuracy.

# %%
best_valid_loss = float('inf')
train_loss_list = list()
valid_loss_list = list()

for epoch in range(EPOCHS):
    start_time = time.monotonic()

    train_loss, train_acc = train(model, X_train, y_train, optimizer, loss_fn, device, batch_size=BATCH_SIZE)
    valid_loss, valid_acc = evaluate(model, X_valid, y_valid, loss_fn, device, batch_size=BATCH_SIZE)

    train_loss_list.append(train_loss)
    valid_loss_list.append(valid_loss)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'aug_100.pt')
    
    end_time = time.monotonic()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')
# Out:
# Epoch: 01 | Epoch Time: 0m 51s
# 	Train Loss: 2.736 | Train Acc: 2.18%
# 	 Val. Loss: 2.638 |  Val. Acc: 51.40%
# Epoch: 02 | Epoch Time: 0m 50s
# 	Train Loss: 2.487 | Train Acc: 56.06%
# 	 Val. Loss: 2.231 |  Val. Acc: 71.47%
# Epoch: 03 | Epoch Time: 0m 50s
# 	Train Loss: 1.569 | Train Acc: 63.01%
# 	 Val. Loss: 0.910 |  Val. Acc: 71.15%
# Epoch: 04 | Epoch Time: 0m 50s
# 	Train Loss: 0.775 | Train Acc: 55.50%
# 	 Val. Loss: 0.684 |  Val. Acc: 71.15%
# Epoch: 05 | Epoch Time: 0m 50s
# 	Train Loss: 0.695 | Train Acc: 55.50%
# 	 Val. Loss: 0.653 |  Val. Acc: 71.15%
# Epoch: 06 | Epoch Time: 0m 50s
# 	Train Loss: 0.673 | Train Acc: 55.60%
# 	 Val. Loss: 0.636 |  Val. Acc: 74.54%
# Epoch: 07 | Epoch Time: 0m 50s
# 	Train Loss: 0.654 | Train Acc: 60.66%
# 	 Val. Loss: 0.618 |  Val. Acc: 80.20%
# Epoch: 08 | Epoch Time: 0m 50s
# 	Train Loss: 0.633 | Train Acc: 69.83%
# 	 Val. Loss: 0.596 |  Val. Acc: 81.15%
# Epoch: 09 | Epoch Time: 0m 50s
# 	Train Loss: 0.607 | Train Acc: 74.68%
# 	 Val. Loss: 0.569 |  Val. Acc: 80.77%
# Epoch: 10 | Epoch Time: 0m 50s
# 	Train Loss: 0.574 | Train Acc: 76.88%
# 	 Val. Loss: 0.538 |  Val. Acc: 80.37%
# Epoch: 11 | Epoch Time: 0m 50s
# 	Train Loss: 0.538 | Train Acc: 78.04%
# 	 Val. Loss: 0.508 |  Val. Acc: 80.25%
# Epoch: 12 | Epoch Time: 0m 50s
# 	Train Loss: 0.505 | Train Acc: 78.78%
# 	 Val. Loss: 0.485 |  Val. Acc: 80.42%
# Epoch: 13 | Epoch Time: 0m 50s
# 	Train Loss: 0.478 | Train Acc: 79.45%
# 	 Val. Loss: 0.469 |  Val. Acc: 80.67%
# Epoch: 14 | Epoch Time: 0m 51s
# 	Train Loss: 0.459 | Train Acc: 80.07%
# 	 Val. Loss: 0.458 |  Val. Acc: 80.87%
# Epoch: 15 | Epoch Time: 0m 50s
# 	Train Loss: 0.446 | Train Acc: 80.47%
# 	 Val. Loss: 0.452 |  Val. Acc: 80.86%
# Epoch: 16 | Epoch Time: 0m 50s
# 	Train Loss: 0.437 | Train Acc: 80.87%
# 	 Val. Loss: 0.449 |  Val. Acc: 80.84%
# Epoch: 17 | Epoch Time: 0m 51s
# 	Train Loss: 0.431 | Train Acc: 81.05%
# 	 Val. Loss: 0.447 |  Val. Acc: 80.62%
# Epoch: 18 | Epoch Time: 0m 51s
# 	Train Loss: 0.427 | Train Acc: 81.19%
# 	 Val. Loss: 0.446 |  Val. Acc: 80.52%
# Epoch: 19 | Epoch Time: 0m 51s
# 	Train Loss: 0.424 | Train Acc: 81.32%
# 	 Val. Loss: 0.446 |  Val. Acc: 80.43%
# Epoch: 20 | Epoch Time: 0m 50s
# 	Train Loss: 0.422 | Train Acc: 81.38%
# 	 Val. Loss: 0.445 |  Val. Acc: 80.43%
# Epoch: 21 | Epoch Time: 0m 50s
# 	Train Loss: 0.420 | Train Acc: 81.43%
# 	 Val. Loss: 0.445 |  Val. Acc: 80.42%
# Epoch: 22 | Epoch Time: 0m 50s
# 	Train Loss: 0.418 | Train Acc: 81.56%
# 	 Val. Loss: 0.444 |  Val. Acc: 80.45%
# Epoch: 23 | Epoch Time: 0m 51s
# 	Train Loss: 0.416 | Train Acc: 81.64%
# 	 Val. Loss: 0.443 |  Val. Acc: 80.49%
# Epoch: 24 | Epoch Time: 0m 50s
# 	Train Loss: 0.415 | Train Acc: 81.74%
# 	 Val. Loss: 0.442 |  Val. Acc: 80.51%
# Epoch: 25 | Epoch Time: 0m 50s
# 	Train Loss: 0.413 | Train Acc: 81.79%
# 	 Val. Loss: 0.442 |  Val. Acc: 80.49%
# Epoch: 26 | Epoch Time: 0m 50s
# 	Train Loss: 0.412 | Train Acc: 81.94%
# 	 Val. Loss: 0.440 |  Val. Acc: 80.52%
# Epoch: 27 | Epoch Time: 0m 50s
# 	Train Loss: 0.410 | Train Acc: 81.94%
# 	 Val. Loss: 0.439 |  Val. Acc: 80.55%
# Epoch: 28 | Epoch Time: 0m 50s
# 	Train Loss: 0.409 | Train Acc: 82.06%
# 	 Val. Loss: 0.438 |  Val. Acc: 80.61%
# Epoch: 29 | Epoch Time: 0m 50s
# 	Train Loss: 0.407 | Train Acc: 82.06%
# 	 Val. Loss: 0.438 |  Val. Acc: 80.65%
# Epoch: 30 | Epoch Time: 0m 50s
# 	Train Loss: 0.406 | Train Acc: 82.16%
# 	 Val. Loss: 0.436 |  Val. Acc: 80.70%
# Epoch: 31 | Epoch Time: 0m 51s
# 	Train Loss: 0.405 | Train Acc: 82.24%
# 	 Val. Loss: 0.435 |  Val. Acc: 80.74%
# Epoch: 32 | Epoch Time: 0m 51s
# 	Train Loss: 0.404 | Train Acc: 82.28%
# 	 Val. Loss: 0.434 |  Val. Acc: 80.76%
# Epoch: 33 | Epoch Time: 0m 50s
# 	Train Loss: 0.402 | Train Acc: 82.36%
# 	 Val. Loss: 0.433 |  Val. Acc: 80.83%
# Epoch: 34 | Epoch Time: 0m 50s
# 	Train Loss: 0.401 | Train Acc: 82.39%
# 	 Val. Loss: 0.432 |  Val. Acc: 80.86%
# Epoch: 35 | Epoch Time: 0m 50s
# 	Train Loss: 0.400 | Train Acc: 82.50%
# 	 Val. Loss: 0.432 |  Val. Acc: 80.91%
# Epoch: 36 | Epoch Time: 0m 50s
# 	Train Loss: 0.398 | Train Acc: 82.53%
# 	 Val. Loss: 0.430 |  Val. Acc: 80.98%
# Epoch: 37 | Epoch Time: 0m 51s
# 	Train Loss: 0.397 | Train Acc: 82.64%
# 	 Val. Loss: 0.429 |  Val. Acc: 81.06%
# Epoch: 38 | Epoch Time: 0m 50s
# 	Train Loss: 0.396 | Train Acc: 82.69%
# 	 Val. Loss: 0.428 |  Val. Acc: 81.12%
# Epoch: 39 | Epoch Time: 0m 51s
# 	Train Loss: 0.395 | Train Acc: 82.74%
# 	 Val. Loss: 0.427 |  Val. Acc: 81.17%
# Epoch: 40 | Epoch Time: 0m 50s
# 	Train Loss: 0.394 | Train Acc: 82.79%
# 	 Val. Loss: 0.426 |  Val. Acc: 81.26%
# Epoch: 41 | Epoch Time: 0m 51s
# 	Train Loss: 0.392 | Train Acc: 82.88%
# 	 Val. Loss: 0.425 |  Val. Acc: 81.31%
# Epoch: 42 | Epoch Time: 0m 51s
# 	Train Loss: 0.391 | Train Acc: 82.93%
# 	 Val. Loss: 0.424 |  Val. Acc: 81.34%
# Epoch: 43 | Epoch Time: 0m 51s
# 	Train Loss: 0.390 | Train Acc: 83.06%
# 	 Val. Loss: 0.422 |  Val. Acc: 81.45%
# Epoch: 44 | Epoch Time: 0m 50s
# 	Train Loss: 0.388 | Train Acc: 83.07%
# 	 Val. Loss: 0.421 |  Val. Acc: 81.54%
# Epoch: 45 | Epoch Time: 0m 51s
# 	Train Loss: 0.387 | Train Acc: 83.15%
# 	 Val. Loss: 0.421 |  Val. Acc: 81.51%
# Epoch: 46 | Epoch Time: 0m 50s
# 	Train Loss: 0.386 | Train Acc: 83.23%
# 	 Val. Loss: 0.419 |  Val. Acc: 81.57%
# Epoch: 47 | Epoch Time: 0m 51s
# 	Train Loss: 0.385 | Train Acc: 83.25%
# 	 Val. Loss: 0.418 |  Val. Acc: 81.61%
# Epoch: 48 | Epoch Time: 0m 51s
# 	Train Loss: 0.383 | Train Acc: 83.32%
# 	 Val. Loss: 0.417 |  Val. Acc: 81.65%
# Epoch: 49 | Epoch Time: 0m 51s
# 	Train Loss: 0.382 | Train Acc: 83.41%
# 	 Val. Loss: 0.415 |  Val. Acc: 81.70%
# Epoch: 50 | Epoch Time: 0m 50s
# 	Train Loss: 0.381 | Train Acc: 83.47%
# 	 Val. Loss: 0.415 |  Val. Acc: 81.73%
# Epoch: 51 | Epoch Time: 0m 50s
# 	Train Loss: 0.379 | Train Acc: 83.56%
# 	 Val. Loss: 0.414 |  Val. Acc: 81.80%
# Epoch: 52 | Epoch Time: 0m 50s
# 	Train Loss: 0.378 | Train Acc: 83.59%
# 	 Val. Loss: 0.411 |  Val. Acc: 81.93%
# Epoch: 53 | Epoch Time: 0m 50s
# 	Train Loss: 0.377 | Train Acc: 83.70%
# 	 Val. Loss: 0.410 |  Val. Acc: 81.97%
# Epoch: 54 | Epoch Time: 0m 51s
# 	Train Loss: 0.376 | Train Acc: 83.72%
# 	 Val. Loss: 0.410 |  Val. Acc: 82.02%
# Epoch: 55 | Epoch Time: 0m 50s
# 	Train Loss: 0.374 | Train Acc: 83.74%
# 	 Val. Loss: 0.408 |  Val. Acc: 82.13%
# Epoch: 56 | Epoch Time: 0m 50s
# 	Train Loss: 0.373 | Train Acc: 83.88%
# 	 Val. Loss: 0.408 |  Val. Acc: 82.16%
# Epoch: 57 | Epoch Time: 0m 50s
# 	Train Loss: 0.372 | Train Acc: 83.92%
# 	 Val. Loss: 0.406 |  Val. Acc: 82.40%
# Epoch: 58 | Epoch Time: 0m 50s
# 	Train Loss: 0.371 | Train Acc: 83.97%
# 	 Val. Loss: 0.405 |  Val. Acc: 82.44%
# Epoch: 59 | Epoch Time: 0m 50s
# 	Train Loss: 0.369 | Train Acc: 84.01%
# 	 Val. Loss: 0.404 |  Val. Acc: 82.50%
# Epoch: 60 | Epoch Time: 0m 50s
# 	Train Loss: 0.368 | Train Acc: 84.08%
# 	 Val. Loss: 0.402 |  Val. Acc: 82.53%
# Epoch: 61 | Epoch Time: 0m 50s
# 	Train Loss: 0.367 | Train Acc: 84.19%
# 	 Val. Loss: 0.401 |  Val. Acc: 82.61%
# Epoch: 62 | Epoch Time: 0m 50s
# 	Train Loss: 0.366 | Train Acc: 84.19%
# 	 Val. Loss: 0.400 |  Val. Acc: 82.64%
# Epoch: 63 | Epoch Time: 0m 50s
# 	Train Loss: 0.365 | Train Acc: 84.26%
# 	 Val. Loss: 0.399 |  Val. Acc: 82.73%
# Epoch: 64 | Epoch Time: 0m 51s
# 	Train Loss: 0.364 | Train Acc: 84.28%
# 	 Val. Loss: 0.398 |  Val. Acc: 82.83%
# Epoch: 65 | Epoch Time: 0m 51s
# 	Train Loss: 0.363 | Train Acc: 84.36%
# 	 Val. Loss: 0.396 |  Val. Acc: 82.89%
# Epoch: 66 | Epoch Time: 0m 50s
# 	Train Loss: 0.362 | Train Acc: 84.40%
# 	 Val. Loss: 0.395 |  Val. Acc: 82.96%
# Epoch: 67 | Epoch Time: 0m 50s
# 	Train Loss: 0.361 | Train Acc: 84.48%
# 	 Val. Loss: 0.394 |  Val. Acc: 83.04%
# Epoch: 68 | Epoch Time: 0m 50s
# 	Train Loss: 0.360 | Train Acc: 84.52%
# 	 Val. Loss: 0.392 |  Val. Acc: 83.14%
# Epoch: 69 | Epoch Time: 0m 50s
# 	Train Loss: 0.359 | Train Acc: 84.59%
# 	 Val. Loss: 0.392 |  Val. Acc: 83.14%
# Epoch: 70 | Epoch Time: 0m 51s
# 	Train Loss: 0.358 | Train Acc: 84.57%
# 	 Val. Loss: 0.389 |  Val. Acc: 83.26%
# Epoch: 71 | Epoch Time: 0m 50s
# 	Train Loss: 0.357 | Train Acc: 84.72%
# 	 Val. Loss: 0.389 |  Val. Acc: 83.25%
# Epoch: 72 | Epoch Time: 0m 50s
# 	Train Loss: 0.357 | Train Acc: 84.73%
# 	 Val. Loss: 0.387 |  Val. Acc: 83.38%
# Epoch: 73 | Epoch Time: 0m 51s
# 	Train Loss: 0.355 | Train Acc: 84.78%
# 	 Val. Loss: 0.387 |  Val. Acc: 83.40%
# Epoch: 74 | Epoch Time: 0m 50s
# 	Train Loss: 0.355 | Train Acc: 84.83%
# 	 Val. Loss: 0.388 |  Val. Acc: 83.41%
# Epoch: 75 | Epoch Time: 0m 51s
# 	Train Loss: 0.354 | Train Acc: 84.85%
# 	 Val. Loss: 0.386 |  Val. Acc: 83.49%
# Epoch: 76 | Epoch Time: 0m 50s
# 	Train Loss: 0.353 | Train Acc: 84.94%
# 	 Val. Loss: 0.387 |  Val. Acc: 83.47%
# Epoch: 77 | Epoch Time: 0m 51s
# 	Train Loss: 0.352 | Train Acc: 84.98%
# 	 Val. Loss: 0.384 |  Val. Acc: 83.64%
# Epoch: 78 | Epoch Time: 0m 51s
# 	Train Loss: 0.351 | Train Acc: 84.98%
# 	 Val. Loss: 0.383 |  Val. Acc: 83.68%
# Epoch: 79 | Epoch Time: 0m 50s
# 	Train Loss: 0.351 | Train Acc: 84.98%
# 	 Val. Loss: 0.381 |  Val. Acc: 83.91%
# Epoch: 80 | Epoch Time: 0m 50s
# 	Train Loss: 0.350 | Train Acc: 85.08%
# 	 Val. Loss: 0.381 |  Val. Acc: 83.92%
# Epoch: 81 | Epoch Time: 0m 51s
# 	Train Loss: 0.350 | Train Acc: 85.10%
# 	 Val. Loss: 0.379 |  Val. Acc: 84.01%
# Epoch: 82 | Epoch Time: 0m 50s
# 	Train Loss: 0.348 | Train Acc: 85.14%
# 	 Val. Loss: 0.379 |  Val. Acc: 83.98%
# Epoch: 83 | Epoch Time: 0m 50s
# 	Train Loss: 0.348 | Train Acc: 85.16%
# 	 Val. Loss: 0.378 |  Val. Acc: 84.05%
# Epoch: 84 | Epoch Time: 0m 50s
# 	Train Loss: 0.347 | Train Acc: 85.23%
# 	 Val. Loss: 0.378 |  Val. Acc: 84.06%
# Epoch: 85 | Epoch Time: 0m 51s
# 	Train Loss: 0.347 | Train Acc: 85.23%
# 	 Val. Loss: 0.376 |  Val. Acc: 84.15%
# Epoch: 86 | Epoch Time: 0m 51s
# 	Train Loss: 0.346 | Train Acc: 85.26%
# 	 Val. Loss: 0.376 |  Val. Acc: 84.18%
# Epoch: 87 | Epoch Time: 0m 50s
# 	Train Loss: 0.345 | Train Acc: 85.35%
# 	 Val. Loss: 0.376 |  Val. Acc: 84.13%
# Epoch: 88 | Epoch Time: 0m 51s
# 	Train Loss: 0.345 | Train Acc: 85.32%
# 	 Val. Loss: 0.374 |  Val. Acc: 84.26%
# Epoch: 89 | Epoch Time: 0m 51s
# 	Train Loss: 0.344 | Train Acc: 85.32%
# 	 Val. Loss: 0.373 |  Val. Acc: 84.30%
# Epoch: 90 | Epoch Time: 0m 50s
# 	Train Loss: 0.344 | Train Acc: 85.41%
# 	 Val. Loss: 0.374 |  Val. Acc: 84.27%
# Epoch: 91 | Epoch Time: 0m 51s
# 	Train Loss: 0.343 | Train Acc: 85.38%
# 	 Val. Loss: 0.371 |  Val. Acc: 84.37%
# Epoch: 92 | Epoch Time: 0m 51s
# 	Train Loss: 0.343 | Train Acc: 85.46%
# 	 Val. Loss: 0.370 |  Val. Acc: 84.43%
# Epoch: 93 | Epoch Time: 0m 50s
# 	Train Loss: 0.342 | Train Acc: 85.52%
# 	 Val. Loss: 0.371 |  Val. Acc: 84.31%
# Epoch: 94 | Epoch Time: 0m 51s
# 	Train Loss: 0.341 | Train Acc: 85.53%
# 	 Val. Loss: 0.369 |  Val. Acc: 84.38%
# Epoch: 95 | Epoch Time: 0m 50s
# 	Train Loss: 0.341 | Train Acc: 85.53%
# 	 Val. Loss: 0.370 |  Val. Acc: 84.34%
# Epoch: 96 | Epoch Time: 0m 51s
# 	Train Loss: 0.340 | Train Acc: 85.56%
# 	 Val. Loss: 0.369 |  Val. Acc: 84.40%
# Epoch: 97 | Epoch Time: 0m 51s
# 	Train Loss: 0.340 | Train Acc: 85.54%
# 	 Val. Loss: 0.367 |  Val. Acc: 84.48%
# Epoch: 98 | Epoch Time: 0m 50s
# 	Train Loss: 0.339 | Train Acc: 85.60%
# 	 Val. Loss: 0.367 |  Val. Acc: 84.48%
# Epoch: 99 | Epoch Time: 0m 50s
# 	Train Loss: 0.339 | Train Acc: 85.66%
# 	 Val. Loss: 0.367 |  Val. Acc: 84.51%
# Epoch: 100 | Epoch Time: 0m 51s
# 	Train Loss: 0.338 | Train Acc: 85.67%
# 	 Val. Loss: 0.366 |  Val. Acc: 84.57%
# Epoch: 101 | Epoch Time: 0m 51s
# 	Train Loss: 0.338 | Train Acc: 85.68%
# 	 Val. Loss: 0.365 |  Val. Acc: 84.61%
# Epoch: 102 | Epoch Time: 0m 51s
# 	Train Loss: 0.337 | Train Acc: 85.70%
# 	 Val. Loss: 0.362 |  Val. Acc: 84.71%
# Epoch: 103 | Epoch Time: 0m 50s
# 	Train Loss: 0.336 | Train Acc: 85.72%
# 	 Val. Loss: 0.367 |  Val. Acc: 84.54%
# Epoch: 104 | Epoch Time: 0m 50s
# 	Train Loss: 0.336 | Train Acc: 85.73%
# 	 Val. Loss: 0.365 |  Val. Acc: 84.60%
# Epoch: 105 | Epoch Time: 0m 50s
# 	Train Loss: 0.336 | Train Acc: 85.79%
# 	 Val. Loss: 0.364 |  Val. Acc: 84.66%
# Epoch: 106 | Epoch Time: 0m 50s
# 	Train Loss: 0.335 | Train Acc: 85.84%
# 	 Val. Loss: 0.363 |  Val. Acc: 84.73%
# Epoch: 107 | Epoch Time: 0m 51s
# 	Train Loss: 0.335 | Train Acc: 85.79%
# 	 Val. Loss: 0.361 |  Val. Acc: 84.78%
# Epoch: 108 | Epoch Time: 0m 51s
# 	Train Loss: 0.334 | Train Acc: 85.83%
# 	 Val. Loss: 0.361 |  Val. Acc: 84.77%
# Epoch: 109 | Epoch Time: 0m 51s
# 	Train Loss: 0.334 | Train Acc: 85.85%
# 	 Val. Loss: 0.358 |  Val. Acc: 84.89%
# Epoch: 110 | Epoch Time: 0m 50s
# 	Train Loss: 0.334 | Train Acc: 85.84%
# 	 Val. Loss: 0.361 |  Val. Acc: 84.81%
# Epoch: 111 | Epoch Time: 0m 50s
# 	Train Loss: 0.333 | Train Acc: 85.84%
# 	 Val. Loss: 0.361 |  Val. Acc: 84.79%
# Epoch: 112 | Epoch Time: 0m 50s
# 	Train Loss: 0.332 | Train Acc: 85.91%
# 	 Val. Loss: 0.360 |  Val. Acc: 84.88%
# Epoch: 113 | Epoch Time: 0m 50s
# 	Train Loss: 0.332 | Train Acc: 85.94%
# 	 Val. Loss: 0.357 |  Val. Acc: 85.03%
# Epoch: 114 | Epoch Time: 0m 50s
# 	Train Loss: 0.331 | Train Acc: 85.99%
# 	 Val. Loss: 0.359 |  Val. Acc: 84.94%
# Epoch: 115 | Epoch Time: 0m 50s
# 	Train Loss: 0.331 | Train Acc: 86.00%
# 	 Val. Loss: 0.358 |  Val. Acc: 85.00%
# Epoch: 116 | Epoch Time: 0m 51s
# 	Train Loss: 0.331 | Train Acc: 86.02%
# 	 Val. Loss: 0.357 |  Val. Acc: 85.10%
# Epoch: 117 | Epoch Time: 0m 51s
# 	Train Loss: 0.330 | Train Acc: 85.99%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.17%
# Epoch: 118 | Epoch Time: 0m 50s
# 	Train Loss: 0.330 | Train Acc: 86.04%
# 	 Val. Loss: 0.358 |  Val. Acc: 85.02%
# Epoch: 119 | Epoch Time: 0m 50s
# 	Train Loss: 0.329 | Train Acc: 86.08%
# 	 Val. Loss: 0.357 |  Val. Acc: 85.08%
# Epoch: 120 | Epoch Time: 0m 50s
# 	Train Loss: 0.329 | Train Acc: 86.07%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.17%
# Epoch: 121 | Epoch Time: 0m 50s
# 	Train Loss: 0.329 | Train Acc: 86.11%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.18%
# Epoch: 122 | Epoch Time: 0m 51s
# 	Train Loss: 0.329 | Train Acc: 86.10%
# 	 Val. Loss: 0.355 |  Val. Acc: 85.18%
# Epoch: 123 | Epoch Time: 0m 51s
# 	Train Loss: 0.328 | Train Acc: 86.13%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.28%
# Epoch: 124 | Epoch Time: 0m 50s
# 	Train Loss: 0.328 | Train Acc: 86.19%
# 	 Val. Loss: 0.352 |  Val. Acc: 85.28%
# Epoch: 125 | Epoch Time: 0m 50s
# 	Train Loss: 0.327 | Train Acc: 86.18%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.25%
# Epoch: 126 | Epoch Time: 0m 50s
# 	Train Loss: 0.327 | Train Acc: 86.16%
# 	 Val. Loss: 0.352 |  Val. Acc: 85.28%
# Epoch: 127 | Epoch Time: 0m 50s
# 	Train Loss: 0.327 | Train Acc: 86.16%
# 	 Val. Loss: 0.352 |  Val. Acc: 85.31%
# Epoch: 128 | Epoch Time: 0m 50s
# 	Train Loss: 0.326 | Train Acc: 86.24%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.36%
# Epoch: 129 | Epoch Time: 0m 50s
# 	Train Loss: 0.326 | Train Acc: 86.26%
# 	 Val. Loss: 0.353 |  Val. Acc: 85.19%
# Epoch: 130 | Epoch Time: 0m 50s
# 	Train Loss: 0.326 | Train Acc: 86.24%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.42%
# Epoch: 131 | Epoch Time: 0m 50s
# 	Train Loss: 0.325 | Train Acc: 86.26%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.42%
# Epoch: 132 | Epoch Time: 0m 50s
# 	Train Loss: 0.325 | Train Acc: 86.29%
# 	 Val. Loss: 0.352 |  Val. Acc: 85.24%
# Epoch: 133 | Epoch Time: 0m 50s
# 	Train Loss: 0.325 | Train Acc: 86.33%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.42%
# Epoch: 134 | Epoch Time: 0m 50s
# 	Train Loss: 0.324 | Train Acc: 86.30%
# 	 Val. Loss: 0.351 |  Val. Acc: 85.31%
# Epoch: 135 | Epoch Time: 0m 50s
# 	Train Loss: 0.324 | Train Acc: 86.36%
# 	 Val. Loss: 0.350 |  Val. Acc: 85.36%
# Epoch: 136 | Epoch Time: 0m 50s
# 	Train Loss: 0.324 | Train Acc: 86.31%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.43%
# Epoch: 137 | Epoch Time: 0m 50s
# 	Train Loss: 0.323 | Train Acc: 86.37%
# 	 Val. Loss: 0.346 |  Val. Acc: 85.55%
# Epoch: 138 | Epoch Time: 0m 50s
# 	Train Loss: 0.323 | Train Acc: 86.36%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.39%
# Epoch: 139 | Epoch Time: 0m 50s
# 	Train Loss: 0.323 | Train Acc: 86.41%
# 	 Val. Loss: 0.345 |  Val. Acc: 85.58%
# Epoch: 140 | Epoch Time: 0m 50s
# 	Train Loss: 0.323 | Train Acc: 86.41%
# 	 Val. Loss: 0.349 |  Val. Acc: 85.39%
# Epoch: 141 | Epoch Time: 0m 50s
# 	Train Loss: 0.322 | Train Acc: 86.37%
# 	 Val. Loss: 0.345 |  Val. Acc: 85.54%
# Epoch: 142 | Epoch Time: 0m 50s
# 	Train Loss: 0.322 | Train Acc: 86.44%
# 	 Val. Loss: 0.344 |  Val. Acc: 85.58%
# Epoch: 143 | Epoch Time: 0m 50s
# 	Train Loss: 0.322 | Train Acc: 86.41%
# 	 Val. Loss: 0.348 |  Val. Acc: 85.41%
# Epoch: 144 | Epoch Time: 0m 50s
# 	Train Loss: 0.321 | Train Acc: 86.45%
# 	 Val. Loss: 0.346 |  Val. Acc: 85.49%
# Epoch: 145 | Epoch Time: 0m 50s
# 	Train Loss: 0.321 | Train Acc: 86.49%
# 	 Val. Loss: 0.345 |  Val. Acc: 85.56%
# Epoch: 146 | Epoch Time: 0m 50s
# 	Train Loss: 0.321 | Train Acc: 86.47%
# 	 Val. Loss: 0.346 |  Val. Acc: 85.48%
# Epoch: 147 | Epoch Time: 0m 50s
# 	Train Loss: 0.320 | Train Acc: 86.48%
# 	 Val. Loss: 0.345 |  Val. Acc: 85.55%
# Epoch: 148 | Epoch Time: 0m 50s
# 	Train Loss: 0.320 | Train Acc: 86.51%
# 	 Val. Loss: 0.346 |  Val. Acc: 85.48%
# Epoch: 149 | Epoch Time: 0m 50s
# 	Train Loss: 0.320 | Train Acc: 86.55%
# 	 Val. Loss: 0.344 |  Val. Acc: 85.59%
# Epoch: 150 | Epoch Time: 0m 50s
# 	Train Loss: 0.320 | Train Acc: 86.56%
# 	 Val. Loss: 0.344 |  Val. Acc: 85.58%
# Epoch: 151 | Epoch Time: 0m 50s
# 	Train Loss: 0.319 | Train Acc: 86.58%
# 	 Val. Loss: 0.342 |  Val. Acc: 85.66%
# Epoch: 152 | Epoch Time: 0m 50s
# 	Train Loss: 0.319 | Train Acc: 86.60%
# 	 Val. Loss: 0.343 |  Val. Acc: 85.63%
# Epoch: 153 | Epoch Time: 0m 50s
# 	Train Loss: 0.318 | Train Acc: 86.62%
# 	 Val. Loss: 0.344 |  Val. Acc: 85.61%
# Epoch: 154 | Epoch Time: 0m 50s
# 	Train Loss: 0.318 | Train Acc: 86.60%
# 	 Val. Loss: 0.341 |  Val. Acc: 85.71%
# Epoch: 155 | Epoch Time: 0m 50s
# 	Train Loss: 0.318 | Train Acc: 86.62%
# 	 Val. Loss: 0.340 |  Val. Acc: 85.71%
# Epoch: 156 | Epoch Time: 0m 50s
# 	Train Loss: 0.318 | Train Acc: 86.58%
# 	 Val. Loss: 0.344 |  Val. Acc: 85.59%
# Epoch: 157 | Epoch Time: 0m 50s
# 	Train Loss: 0.318 | Train Acc: 86.60%
# 	 Val. Loss: 0.344 |  Val. Acc: 85.55%
# Epoch: 158 | Epoch Time: 0m 50s
# 	Train Loss: 0.317 | Train Acc: 86.64%
# 	 Val. Loss: 0.342 |  Val. Acc: 85.64%
# Epoch: 159 | Epoch Time: 0m 50s
# 	Train Loss: 0.317 | Train Acc: 86.63%
# 	 Val. Loss: 0.342 |  Val. Acc: 85.62%
# Epoch: 160 | Epoch Time: 0m 50s
# 	Train Loss: 0.316 | Train Acc: 86.66%
# 	 Val. Loss: 0.343 |  Val. Acc: 85.59%
# Epoch: 161 | Epoch Time: 0m 50s
# 	Train Loss: 0.316 | Train Acc: 86.71%
# 	 Val. Loss: 0.344 |  Val. Acc: 85.52%
# Epoch: 162 | Epoch Time: 0m 50s
# 	Train Loss: 0.316 | Train Acc: 86.73%
# 	 Val. Loss: 0.339 |  Val. Acc: 85.71%
# Epoch: 163 | Epoch Time: 0m 51s
# 	Train Loss: 0.316 | Train Acc: 86.65%
# 	 Val. Loss: 0.338 |  Val. Acc: 85.80%
# Epoch: 164 | Epoch Time: 0m 50s
# 	Train Loss: 0.316 | Train Acc: 86.73%
# 	 Val. Loss: 0.342 |  Val. Acc: 85.60%
# Epoch: 166 | Epoch Time: 0m 50s
# 	Train Loss: 0.315 | Train Acc: 86.75%
# 	 Val. Loss: 0.339 |  Val. Acc: 85.74%
# Epoch: 167 | Epoch Time: 0m 50s
# 	Train Loss: 0.315 | Train Acc: 86.74%
# 	 Val. Loss: 0.340 |  Val. Acc: 85.70%
# Epoch: 168 | Epoch Time: 0m 50s
# 	Train Loss: 0.315 | Train Acc: 86.79%
# 	 Val. Loss: 0.340 |  Val. Acc: 85.69%
# Epoch: 169 | Epoch Time: 0m 51s
# 	Train Loss: 0.314 | Train Acc: 86.79%
# 	 Val. Loss: 0.337 |  Val. Acc: 85.81%
# Epoch: 170 | Epoch Time: 0m 50s
# 	Train Loss: 0.314 | Train Acc: 86.81%
# 	 Val. Loss: 0.338 |  Val. Acc: 85.75%
# Epoch: 171 | Epoch Time: 0m 50s
# 	Train Loss: 0.314 | Train Acc: 86.80%
# 	 Val. Loss: 0.340 |  Val. Acc: 85.68%
# Epoch: 172 | Epoch Time: 0m 50s
# 	Train Loss: 0.314 | Train Acc: 86.79%
# 	 Val. Loss: 0.337 |  Val. Acc: 85.79%
# Epoch: 173 | Epoch Time: 0m 51s
# 	Train Loss: 0.314 | Train Acc: 86.83%
# 	 Val. Loss: 0.337 |  Val. Acc: 85.81%
# Epoch: 174 | Epoch Time: 0m 50s
# 	Train Loss: 0.313 | Train Acc: 86.82%
# 	 Val. Loss: 0.337 |  Val. Acc: 85.79%
# Epoch: 175 | Epoch Time: 0m 50s
# 	Train Loss: 0.313 | Train Acc: 86.83%
# 	 Val. Loss: 0.338 |  Val. Acc: 85.77%
# Epoch: 176 | Epoch Time: 0m 51s
# 	Train Loss: 0.313 | Train Acc: 86.87%
# 	 Val. Loss: 0.335 |  Val. Acc: 85.88%
# Epoch: 177 | Epoch Time: 0m 50s
# 	Train Loss: 0.312 | Train Acc: 86.86%
# 	 Val. Loss: 0.336 |  Val. Acc: 85.81%
# Epoch: 178 | Epoch Time: 0m 50s
# 	Train Loss: 0.312 | Train Acc: 86.89%
# 	 Val. Loss: 0.337 |  Val. Acc: 85.78%
# Epoch: 179 | Epoch Time: 0m 50s
# 	Train Loss: 0.312 | Train Acc: 86.85%
# 	 Val. Loss: 0.339 |  Val. Acc: 85.67%
# Epoch: 180 | Epoch Time: 0m 50s
# 	Train Loss: 0.312 | Train Acc: 86.87%
# 	 Val. Loss: 0.337 |  Val. Acc: 85.74%
# Epoch: 181 | Epoch Time: 0m 50s
# 	Train Loss: 0.311 | Train Acc: 86.95%
# 	 Val. Loss: 0.338 |  Val. Acc: 85.70%
# Epoch: 182 | Epoch Time: 0m 50s
# 	Train Loss: 0.311 | Train Acc: 86.90%
# 	 Val. Loss: 0.335 |  Val. Acc: 85.82%
# Epoch: 183 | Epoch Time: 0m 51s
# 	Train Loss: 0.311 | Train Acc: 86.94%
# 	 Val. Loss: 0.335 |  Val. Acc: 85.85%
# Epoch: 184 | Epoch Time: 0m 50s
# 	Train Loss: 0.311 | Train Acc: 86.93%
# 	 Val. Loss: 0.336 |  Val. Acc: 85.77%
# Epoch: 185 | Epoch Time: 0m 50s
# 	Train Loss: 0.311 | Train Acc: 86.94%
# 	 Val. Loss: 0.337 |  Val. Acc: 85.73%
# Epoch: 186 | Epoch Time: 0m 50s
# 	Train Loss: 0.311 | Train Acc: 86.95%
# 	 Val. Loss: 0.334 |  Val. Acc: 85.86%
# Epoch: 187 | Epoch Time: 0m 50s
# 	Train Loss: 0.311 | Train Acc: 86.92%
# 	 Val. Loss: 0.335 |  Val. Acc: 85.81%
# Epoch: 188 | Epoch Time: 0m 50s
# 	Train Loss: 0.310 | Train Acc: 86.96%
# 	 Val. Loss: 0.335 |  Val. Acc: 85.81%
# Epoch: 189 | Epoch Time: 0m 50s
# 	Train Loss: 0.310 | Train Acc: 86.97%
# 	 Val. Loss: 0.334 |  Val. Acc: 85.84%
# Epoch: 190 | Epoch Time: 0m 50s
# 	Train Loss: 0.310 | Train Acc: 87.01%
# 	 Val. Loss: 0.335 |  Val. Acc: 85.82%
# Epoch: 191 | Epoch Time: 0m 50s
# 	Train Loss: 0.309 | Train Acc: 87.00%
# 	 Val. Loss: 0.332 |  Val. Acc: 85.96%
# Epoch: 192 | Epoch Time: 0m 50s
# 	Train Loss: 0.309 | Train Acc: 87.03%
# 	 Val. Loss: 0.336 |  Val. Acc: 85.77%
# Epoch: 193 | Epoch Time: 0m 50s
# 	Train Loss: 0.309 | Train Acc: 87.01%
# 	 Val. Loss: 0.334 |  Val. Acc: 85.83%
# Epoch: 194 | Epoch Time: 0m 50s
# 	Train Loss: 0.309 | Train Acc: 87.07%
# 	 Val. Loss: 0.333 |  Val. Acc: 85.86%
# Epoch: 195 | Epoch Time: 0m 50s
# 	Train Loss: 0.308 | Train Acc: 87.04%
# 	 Val. Loss: 0.334 |  Val. Acc: 85.84%
# Epoch: 196 | Epoch Time: 0m 50s
# 	Train Loss: 0.308 | Train Acc: 87.07%
# 	 Val. Loss: 0.331 |  Val. Acc: 85.99%
# Epoch: 197 | Epoch Time: 0m 50s
# 	Train Loss: 0.308 | Train Acc: 87.09%
# 	 Val. Loss: 0.333 |  Val. Acc: 85.88%
# Epoch: 198 | Epoch Time: 0m 50s
# 	Train Loss: 0.308 | Train Acc: 87.08%
# 	 Val. Loss: 0.333 |  Val. Acc: 85.88%
# Epoch: 199 | Epoch Time: 0m 50s
# 	Train Loss: 0.308 | Train Acc: 87.13%
# 	 Val. Loss: 0.333 |  Val. Acc: 85.84%
# Epoch: 200 | Epoch Time: 0m 50s
# 	Train Loss: 0.308 | Train Acc: 87.05%
# 	 Val. Loss: 0.332 |  Val. Acc: 85.89%

# %% [markdown]
# **Load the parameters of the best model**

# %%
model.load_state_dict(torch.load('aug_100.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### **Examining the Model**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, balanced_accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# **Visualizing loss of train set and valid set**

# %%
epoch_list = np.arange(1, EPOCHS + 1)

# %%
fig, ax = plt.subplots(figsize=(14,8))

ax.plot(epoch_list, train_loss_list, label='train loss')
ax.plot(epoch_list, valid_loss_list, label='validate loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')

ax.legend()
plt.show()

# %% [markdown]
# **Get the predictions**

# %%
def get_predictions(model, X, y, device, batch_size):
    
    model.eval()
    y_predict = []

    with torch.no_grad():
        for (batchX, batchY) in next_batch(X, y, batch_size):
            X = torch.from_numpy(batchX).to(device)

            y_tmp = model(X)
            top_pred = y_tmp.argmax(1, keepdim = True)

            for i in top_pred:
                y_predict.append(i.item())

    return np.array(y_predict)

# %%
y_predict = get_predictions(model, X_test, y_test, device, batch_size=BATCH_SIZE)

# %% [markdown]
# **Confusion matrix**

# %%
cm = confusion_matrix(y_test, y_predict)
print(cm)
# Out:
# [[34140  5288]
#  [ 2176 13441]]

# %%
pd_cm = pd.DataFrame(cm, index = ['negative', 'positive'], columns = ['negative', 'positive'])

# %%
plt.figure(figsize=(14,10))
ax = plt.axes()
sn.heatmap(pd_cm, annot=True, fmt='d', cmap='Blues')
ax.set_xlabel('Predict label')
ax.set_ylabel('True label')

plt.show()

# %% [markdown]
# **Quantifying the quality of predictions**

# %%
def show_metrics_scores(y_test, y_predict):
    print(f'Accuracy score\t\t: {accuracy_score(y_test, y_predict):.4f}\n')
    print(f'Balanced accuracy score\t: {balanced_accuracy_score(y_test, y_predict):.4f}\n')
    print(f'F1 score\t\t: {f1_score(y_test, y_predict):.4f}\n')
    print(f'Recall score\t\t: {recall_score(y_test, y_predict):.4f}')

# %%
show_metrics_scores(y_test, y_predict)
# Out:
# Accuracy score		: 0.8644
#
# Balanced accuracy score	: 0.8633
#
# F1 score		: 0.7827
#
# Recall score		: 0.8607
