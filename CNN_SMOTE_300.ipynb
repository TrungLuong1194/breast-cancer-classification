# %% [markdown]
# # **Connect to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/Colab\ Notebooks/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %% [markdown]
# # **Preprocessing the dataset**
#
# - Load the data from Google Drive.
# - In Google Drive, have 3 directories: train_data - valid_data - test_data.
# - In each folder, data is stored in h5py format.
# - Standardization (z-score).

# %%
import numpy as np
import h5py

# %%
def preprocessing_dataset(num_file, filename_prefix):
    X = []
    y = []

    # Load the data from h5py
    for i in range(1, num_file):
        
        filename = filename_prefix + str(i) + '.hdf5'
        print('Loading batch ' + str(i) + ' ...')

        with h5py.File(filename, 'r') as f:
            for j in f['X'][:]:
                X.append(j)

            for j in f['y'][:]:
                y.append(j)

    # Convert to numpy array
    X = np.array(X)
    y = np.array(y)

    # Calculate the mean of each channel
    mean_0 = X[:, 0, :, :].mean()
    mean_1 = X[:, 1, :, :].mean()
    mean_2 = X[:, 2, :, :].mean()

    # Calculate the standard deviation of each channel
    std_0 = X[:, 0, :, :].std()
    std_1 = X[:, 1, :, :].std()
    std_2 = X[:, 2, :, :].std()

    # Standardization
    X[:, 0, :, :] = (X[:, 0, :, :] - mean_0) / std_0
    X[:, 1, :, :] = (X[:, 1, :, :] - mean_1) / std_1
    X[:, 2, :, :] = (X[:, 2, :, :] - mean_2) / std_2

    return X, y

# %% [markdown]
# **Configure the dataset**

# %%
train_num_file = 10
train_filename_prefix = 'train_data/X_train_'

valid_num_file = 4
valid_filename_prefix = 'valid_data/X_valid_'

test_num_file = 4
test_filename_prefix = 'test_data/X_test_'

# %% [markdown]
# ### **Load the training set**

# %%
X_train, y_train = preprocessing_dataset(train_num_file, train_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...
# Loading batch 4 ...
# Loading batch 5 ...
# Loading batch 6 ...
# Loading batch 7 ...
# Loading batch 8 ...
# Loading batch 9 ...

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (165133, 3, 50, 50)
# (165133,)

# %% [markdown]
# ### **Load the validation set**

# %%
X_valid, y_valid = preprocessing_dataset(valid_num_file, valid_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...

# %%
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (55044, 3, 50, 50)
# (55044,)

# %% [markdown]
# ### **Load the test set**

# %%
X_test, y_test = preprocessing_dataset(test_num_file, test_filename_prefix)
# Out:
# Loading batch 1 ...
# Loading batch 2 ...
# Loading batch 3 ...

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (55045, 3, 50, 50)
# (55045,)

# %% [markdown]
# # **Building Model Convolution Neural Network**

# %%
import math
import time
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import torch
import torch.nn as nn
from torch import optim
from imblearn.over_sampling import SMOTE
import collections

from warnings import simplefilter, filterwarnings
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ### **Parameters of the model**

# %%
EPOCHS = 80
BATCH_SIZE = 128
LR = 1e-6

# %% [markdown]
# ### **Defining the Model**

# %% [markdown]
# **Model description:**
#
# - Input model is RGB image data (3 color channels, 50 pixels height, 50 pixels width)
# - Transform input image to multi-dimensional matrix with size 3 - 50 - 50.
#
#
# **Activation function**
#
# - The ReLU is the most used activation function in the world right now. Since, it is used in almost all the convolutional neural networks or deep learning.
# - Computationally efficient—allows the network to converge very quickly.
# - Non-linear—although it looks like a linear function, ReLU has a derivative function and allows for backpropagation.
#
# ![ReLU-activation-function.png](data:image/png;base64,...)
#
# **Avoid overfitting**
#
# To avoid overfitting in neural networks, use two methods of Dropout and Batch normalization.
# - **Dropout**: is one of the most commonly used and the most powerful regularization techniques used in deep learning. Dropout is applied to intermediate layers of the model during the training time. Let's look at an example of how dropout is applied on a linear layer's output that generates 10 values:
#
#   + The figure shows what happens when dropout is applied to the linear layer output with a threshold value of 0.2. It randomly masks or zeros 20% of data, so that the model will not be dependent on a particular set of weights or patterns, thus overfitting.
#
# ![a.png](data:image/png;base64,...)
#
# - **Batch normalization**: (also known as batch norm) is a method used to make artificial neural networks faster and more stable through normalization of the input layer by re-centering and re-scaling. To increase the stability of a neural network, batch normalization normalizes the output of a previous activation layer by subtracting the batch mean and dividing by the batch standard deviation.

# %%
class CNN(nn.Module):
  
    def __init__(self):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=2)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=2)
        self.conv5 = nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=2)

        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(128)
        self.bn4 = nn.BatchNorm2d(256)
        self.bn5 = nn.BatchNorm2d(512)

        self.mp = nn.MaxPool2d(kernel_size=2)
        self.relu = nn.ReLU()
        self.do = nn.Dropout()

        self.fc1 = nn.Linear(4608, 1024)
        self.fc2 = nn.Linear(1024, 256)
        self.fc3 = nn.Linear(256, 64)
        self.fc4 = nn.Linear(64, 16)
        self.fc5 = nn.Linear(16, 2)

    def forward(self, x):
        x = self.mp(self.relu(self.bn1(self.conv1(x))))
        x = self.mp(self.relu(self.bn2(self.conv2(x))))
        x = self.mp(self.relu(self.bn3(self.conv3(x))))
        x = self.mp(self.relu(self.bn4(self.conv4(x))))
        x = self.do(self.mp(self.relu(self.bn5(self.conv5(x)))))

        x = x.view(x.shape[0], -1)

        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.relu(self.fc4(x))
        out = self.fc5(x)

        return out

# %%
model = CNN()
print(model)
# Out:
# CNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (conv5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (mp): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (do): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=4608, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=16, bias=True)
#   (fc5): Linear(in_features=16, out_features=2, bias=True)
# )

# %% [markdown]
# **Calculate the number of trainable parameters (weights and biases)**

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 6,570,098 trainable parameters

# %% [markdown]
# **Optimization Algorithm**
#
# - Steps to optimization
#
#   + Pass a batch of data through your model.
#   + Calculate the loss of your batch by comparing your model's predictions against the actual labels.
#   + Calculate the gradient of each of your parameters with respect to the loss.
#   + Update each of your parameters by subtracting their gradient multiplied by a small learning rate parameter.

# %%
optimizer = optim.Adam(model.parameters(), lr=LR)

# %% [markdown]
# **Loss Fuction**
#
# - **Cross-entropy** can be used to define a loss function in machine learning and optimization.

# %%
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# **Calculate the accuracy**
# - This takes the index of the highest value for your prediction and compares it against the actual class label. Then divide how many our model got correct by the amount in the batch to calculate accuracy across the batch.

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %% [markdown]
# **Create mini-batch**

# %%
def next_batch(X, y, batch_size):
    # Mini-batch
    for i in np.arange(0, X.shape[0], batch_size):
        yield X[i:i + batch_size], y[i:i + batch_size]

# %% [markdown]
# **Transform the model and data to GPU**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = model.to(device)
loss_fn = loss_fn.to(device)

# %% [markdown]
# ### **Training the Model**

# %% [markdown]
# **Define Traning step**
# - Put the model into train mode: **model.train()**
# - Iterate over batches of data.
# - Transform the batch to GPU mode.
# - Clear the gradients calculated from the last batch.
# - Impliment model for batch of images: x, get predictions, y_pred.
# - Calculate the loss between prediction labels and the actual labels.
# - Calculate the accuracy between prediction labels and the actual labels.
# - Calculate the gradients of each parameter.
# - Update the parameters by taking optimizer step.
# - Return the loss and the accuracy of epoch.

# %%
def train(model, X, y, optimizer, loss_fn, device, batch_size):
    epoch_loss = 0
    epoch_acc = 0
    
    # Impliment train mode
    model.train()
    
    for (batchX, batchY) in next_batch(X, y, batch_size):
        # SMOTE
        x_tmp = batchX.reshape(batchX.shape[0], 3 * 50 * 50)
        y_tmp = batchY

        count = collections.Counter(y_tmp)

        x_smote, y_smote = SMOTE(sampling_strategy={0: count[0], 1: count[0] * 3}, k_neighbors=3).fit_resample(x_tmp, y_tmp)
        x_smote = x_smote.reshape(x_smote.shape[0], 3, 50, 50)

        # Create tensor
        x = torch.from_numpy(x_smote).to(device)
        y = torch.from_numpy(y_smote).to(device)
        
        # Clear the gradients calculated from the last batch
        optimizer.zero_grad()
                
        y_pred = model(x)

        loss = loss_fn(y_pred, y)
        acc = calculate_accuracy(y_pred, y)
        
        # Calculate the gradients of each parameter
        loss.backward()
        
        # Update the parameters
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
        
    num_of_batchs = math.ceil(len(X) / batch_size)
    return epoch_loss / num_of_batchs, epoch_acc / num_of_batchs

# %% [markdown]
# **Define Evaluation step**
#
# - Similar the training step. The differences are:
#   + Put the model into evalution mode: **model.eval()**
#   + Don't calculate the gradients of each parameter.
#   + Don't update the parameters by taking optimizer step.
#
# - **torch.no_grad()** ensures that gradients are not calculated for whatever is inside the with block. As our model will not have to calculate gradients it will be faster and use less memory.

# %%
def evaluate(model, X, y, loss_fn, device, batch_size):
    epoch_loss = 0
    epoch_acc = 0
    
    # Impliment evaluation mode
    model.eval()
    
    with torch.no_grad():
        for (batchX, batchY) in next_batch(X, y, batch_size):
            x = torch.from_numpy(batchX).to(device)
            y = torch.from_numpy(batchY).to(device)

            y_pred = model(x)

            loss = loss_fn(y_pred, y)
            acc = calculate_accuracy(y_pred, y)

            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    num_of_batchs = math.ceil(len(X) / batch_size)
    return epoch_loss / num_of_batchs, epoch_acc / num_of_batchs

# %% [markdown]
# **Calculate the time need to run each epoch**

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %% [markdown]
# **Training the Model**
# - Iterate over epochs.
# - In each epochs:
#   - Training the Model with training set.
#   - Evaluate the Model with validation set.
#   - Check the best validation loss and save the model parameters
#   - Print the result metrics: Loss and Accuracy.

# %%
best_valid_loss = float('inf')
train_loss_list = list()
valid_loss_list = list()

for epoch in range(EPOCHS):
    start_time = time.monotonic()

    train_loss, train_acc = train(model, X_train, y_train, optimizer, loss_fn, device, batch_size=BATCH_SIZE)
    valid_loss, valid_acc = evaluate(model, X_valid, y_valid, loss_fn, device, batch_size=BATCH_SIZE)

    train_loss_list.append(train_loss)
    valid_loss_list.append(valid_loss)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'smote_v3.pt')
    
    end_time = time.monotonic()

    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    print(f'Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}%')
# Out:
# Epoch: 01 | Epoch Time: 1m 54s
# 	Train Loss: 0.396 | Train Acc: 83.58%
# 	 Val. Loss: 0.535 |  Val. Acc: 78.87%
# Epoch: 02 | Epoch Time: 1m 54s
# 	Train Loss: 0.246 | Train Acc: 90.14%
# 	 Val. Loss: 0.482 |  Val. Acc: 80.38%
# Epoch: 03 | Epoch Time: 1m 54s
# 	Train Loss: 0.229 | Train Acc: 90.78%
# 	 Val. Loss: 0.457 |  Val. Acc: 81.16%
# Epoch: 04 | Epoch Time: 1m 54s
# 	Train Loss: 0.220 | Train Acc: 91.18%
# 	 Val. Loss: 0.435 |  Val. Acc: 81.78%
# Epoch: 05 | Epoch Time: 1m 54s
# 	Train Loss: 0.214 | Train Acc: 91.40%
# 	 Val. Loss: 0.432 |  Val. Acc: 82.02%
# Epoch: 06 | Epoch Time: 1m 54s
# 	Train Loss: 0.209 | Train Acc: 91.58%
# 	 Val. Loss: 0.432 |  Val. Acc: 82.08%
# Epoch: 07 | Epoch Time: 1m 54s
# 	Train Loss: 0.206 | Train Acc: 91.73%
# 	 Val. Loss: 0.415 |  Val. Acc: 82.69%
# Epoch: 08 | Epoch Time: 1m 54s
# 	Train Loss: 0.203 | Train Acc: 91.85%
# 	 Val. Loss: 0.410 |  Val. Acc: 82.94%
# Epoch: 09 | Epoch Time: 1m 54s
# 	Train Loss: 0.201 | Train Acc: 91.90%
# 	 Val. Loss: 0.416 |  Val. Acc: 82.78%
# Epoch: 10 | Epoch Time: 1m 54s
# 	Train Loss: 0.199 | Train Acc: 92.01%
# 	 Val. Loss: 0.410 |  Val. Acc: 83.03%
# Epoch: 11 | Epoch Time: 1m 55s
# 	Train Loss: 0.197 | Train Acc: 92.09%
# 	 Val. Loss: 0.411 |  Val. Acc: 83.01%
# Epoch: 12 | Epoch Time: 1m 54s
# 	Train Loss: 0.195 | Train Acc: 92.13%
# 	 Val. Loss: 0.406 |  Val. Acc: 83.12%
# Epoch: 13 | Epoch Time: 1m 54s
# 	Train Loss: 0.193 | Train Acc: 92.25%
# 	 Val. Loss: 0.399 |  Val. Acc: 83.35%
# Epoch: 14 | Epoch Time: 1m 54s
# 	Train Loss: 0.192 | Train Acc: 92.29%
# 	 Val. Loss: 0.405 |  Val. Acc: 83.18%
# Epoch: 15 | Epoch Time: 1m 54s
# 	Train Loss: 0.190 | Train Acc: 92.37%
# 	 Val. Loss: 0.395 |  Val. Acc: 83.49%
# Epoch: 16 | Epoch Time: 1m 54s
# 	Train Loss: 0.188 | Train Acc: 92.47%
# 	 Val. Loss: 0.398 |  Val. Acc: 83.48%
# Epoch: 17 | Epoch Time: 1m 55s
# 	Train Loss: 0.187 | Train Acc: 92.47%
# 	 Val. Loss: 0.404 |  Val. Acc: 83.17%
# Epoch: 18 | Epoch Time: 1m 56s
# 	Train Loss: 0.186 | Train Acc: 92.53%
# 	 Val. Loss: 0.390 |  Val. Acc: 83.63%
# Epoch: 19 | Epoch Time: 1m 55s
# 	Train Loss: 0.185 | Train Acc: 92.60%
# 	 Val. Loss: 0.396 |  Val. Acc: 83.47%
# Epoch: 20 | Epoch Time: 1m 56s
# 	Train Loss: 0.184 | Train Acc: 92.63%
# 	 Val. Loss: 0.392 |  Val. Acc: 83.68%
# Epoch: 21 | Epoch Time: 1m 56s
# 	Train Loss: 0.183 | Train Acc: 92.65%
# 	 Val. Loss: 0.389 |  Val. Acc: 83.76%
# Epoch: 22 | Epoch Time: 1m 55s
# 	Train Loss: 0.181 | Train Acc: 92.72%
# 	 Val. Loss: 0.401 |  Val. Acc: 83.28%
# Epoch: 23 | Epoch Time: 1m 56s
# 	Train Loss: 0.180 | Train Acc: 92.80%
# 	 Val. Loss: 0.391 |  Val. Acc: 83.72%
# Epoch: 24 | Epoch Time: 1m 56s
# 	Train Loss: 0.180 | Train Acc: 92.81%
# 	 Val. Loss: 0.388 |  Val. Acc: 83.86%
# Epoch: 25 | Epoch Time: 1m 56s
# 	Train Loss: 0.179 | Train Acc: 92.85%
# 	 Val. Loss: 0.389 |  Val. Acc: 83.76%
# Epoch: 26 | Epoch Time: 1m 55s
# 	Train Loss: 0.178 | Train Acc: 92.86%
# 	 Val. Loss: 0.387 |  Val. Acc: 83.84%
# Epoch: 27 | Epoch Time: 1m 55s
# 	Train Loss: 0.177 | Train Acc: 92.91%
# 	 Val. Loss: 0.394 |  Val. Acc: 83.61%
# Epoch: 28 | Epoch Time: 1m 54s
# 	Train Loss: 0.176 | Train Acc: 92.99%
# 	 Val. Loss: 0.379 |  Val. Acc: 84.26%
# Epoch: 29 | Epoch Time: 1m 54s
# 	Train Loss: 0.175 | Train Acc: 93.02%
# 	 Val. Loss: 0.390 |  Val. Acc: 83.77%
# Epoch: 30 | Epoch Time: 1m 54s
# 	Train Loss: 0.174 | Train Acc: 93.03%
# 	 Val. Loss: 0.385 |  Val. Acc: 84.03%
# Epoch: 31 | Epoch Time: 1m 55s
# 	Train Loss: 0.174 | Train Acc: 93.08%
# 	 Val. Loss: 0.382 |  Val. Acc: 84.22%
# Epoch: 32 | Epoch Time: 1m 56s
# 	Train Loss: 0.173 | Train Acc: 93.10%
# 	 Val. Loss: 0.386 |  Val. Acc: 84.00%
# Epoch: 33 | Epoch Time: 1m 54s
# 	Train Loss: 0.172 | Train Acc: 93.12%
# 	 Val. Loss: 0.381 |  Val. Acc: 84.20%
# Epoch: 34 | Epoch Time: 1m 54s
# 	Train Loss: 0.171 | Train Acc: 93.16%
# 	 Val. Loss: 0.381 |  Val. Acc: 84.28%
# Epoch: 35 | Epoch Time: 1m 54s
# 	Train Loss: 0.171 | Train Acc: 93.18%
# 	 Val. Loss: 0.386 |  Val. Acc: 84.02%
# Epoch: 36 | Epoch Time: 1m 56s
# 	Train Loss: 0.170 | Train Acc: 93.24%
# 	 Val. Loss: 0.385 |  Val. Acc: 84.13%
# Epoch: 37 | Epoch Time: 1m 54s
# 	Train Loss: 0.169 | Train Acc: 93.27%
# 	 Val. Loss: 0.385 |  Val. Acc: 84.16%
# Epoch: 38 | Epoch Time: 1m 54s
# 	Train Loss: 0.169 | Train Acc: 93.28%
# 	 Val. Loss: 0.375 |  Val. Acc: 84.55%
# Epoch: 39 | Epoch Time: 1m 54s
# 	Train Loss: 0.168 | Train Acc: 93.33%
# 	 Val. Loss: 0.377 |  Val. Acc: 84.47%
# Epoch: 40 | Epoch Time: 1m 53s
# 	Train Loss: 0.167 | Train Acc: 93.36%
# 	 Val. Loss: 0.383 |  Val. Acc: 84.12%
# Epoch: 41 | Epoch Time: 1m 54s
# 	Train Loss: 0.167 | Train Acc: 93.37%
# 	 Val. Loss: 0.378 |  Val. Acc: 84.48%
# Epoch: 42 | Epoch Time: 1m 54s
# 	Train Loss: 0.166 | Train Acc: 93.38%
# 	 Val. Loss: 0.378 |  Val. Acc: 84.54%
# Epoch: 43 | Epoch Time: 1m 53s
# 	Train Loss: 0.165 | Train Acc: 93.42%
# 	 Val. Loss: 0.374 |  Val. Acc: 84.68%
# Epoch: 44 | Epoch Time: 1m 52s
# 	Train Loss: 0.165 | Train Acc: 93.43%
# 	 Val. Loss: 0.385 |  Val. Acc: 84.09%
# Epoch: 45 | Epoch Time: 1m 53s
# 	Train Loss: 0.165 | Train Acc: 93.46%
# 	 Val. Loss: 0.380 |  Val. Acc: 84.34%
# Epoch: 46 | Epoch Time: 1m 53s
# 	Train Loss: 0.164 | Train Acc: 93.50%
# 	 Val. Loss: 0.374 |  Val. Acc: 84.63%
# Epoch: 47 | Epoch Time: 1m 54s
# 	Train Loss: 0.163 | Train Acc: 93.52%
# 	 Val. Loss: 0.376 |  Val. Acc: 84.65%
# Epoch: 48 | Epoch Time: 1m 53s
# 	Train Loss: 0.162 | Train Acc: 93.60%
# 	 Val. Loss: 0.376 |  Val. Acc: 84.57%
# Epoch: 49 | Epoch Time: 1m 53s
# 	Train Loss: 0.162 | Train Acc: 93.60%
# 	 Val. Loss: 0.386 |  Val. Acc: 84.10%
# Epoch: 50 | Epoch Time: 1m 54s
# 	Train Loss: 0.161 | Train Acc: 93.65%
# 	 Val. Loss: 0.382 |  Val. Acc: 84.33%
# Epoch: 51 | Epoch Time: 1m 55s
# 	Train Loss: 0.161 | Train Acc: 93.67%
# 	 Val. Loss: 0.384 |  Val. Acc: 84.32%
# Epoch: 52 | Epoch Time: 1m 55s
# 	Train Loss: 0.160 | Train Acc: 93.64%
# 	 Val. Loss: 0.376 |  Val. Acc: 84.75%
# Epoch: 53 | Epoch Time: 1m 55s
# 	Train Loss: 0.160 | Train Acc: 93.70%
# 	 Val. Loss: 0.377 |  Val. Acc: 84.58%
# Epoch: 54 | Epoch Time: 1m 55s
# 	Train Loss: 0.159 | Train Acc: 93.73%
# 	 Val. Loss: 0.384 |  Val. Acc: 84.18%
# Epoch: 55 | Epoch Time: 1m 55s
# 	Train Loss: 0.158 | Train Acc: 93.76%
# 	 Val. Loss: 0.380 |  Val. Acc: 84.59%
# Epoch: 56 | Epoch Time: 1m 55s
# 	Train Loss: 0.158 | Train Acc: 93.78%
# 	 Val. Loss: 0.372 |  Val. Acc: 84.85%
# Epoch: 57 | Epoch Time: 1m 55s
# 	Train Loss: 0.157 | Train Acc: 93.79%
# 	 Val. Loss: 0.377 |  Val. Acc: 84.55%
# Epoch: 58 | Epoch Time: 1m 55s
# 	Train Loss: 0.157 | Train Acc: 93.78%
# 	 Val. Loss: 0.373 |  Val. Acc: 84.80%
# Epoch: 59 | Epoch Time: 1m 54s
# 	Train Loss: 0.156 | Train Acc: 93.83%
# 	 Val. Loss: 0.371 |  Val. Acc: 84.95%
# Epoch: 60 | Epoch Time: 1m 53s
# 	Train Loss: 0.155 | Train Acc: 93.86%
# 	 Val. Loss: 0.380 |  Val. Acc: 84.53%
# Epoch: 61 | Epoch Time: 1m 53s
# 	Train Loss: 0.155 | Train Acc: 93.89%
# 	 Val. Loss: 0.368 |  Val. Acc: 85.02%
# Epoch: 62 | Epoch Time: 1m 53s
# 	Train Loss: 0.155 | Train Acc: 93.88%
# 	 Val. Loss: 0.373 |  Val. Acc: 84.80%
# Epoch: 63 | Epoch Time: 1m 53s
# 	Train Loss: 0.153 | Train Acc: 93.97%
# 	 Val. Loss: 0.375 |  Val. Acc: 84.68%
# Epoch: 64 | Epoch Time: 1m 53s
# 	Train Loss: 0.153 | Train Acc: 94.00%
# 	 Val. Loss: 0.380 |  Val. Acc: 84.45%
# Epoch: 65 | Epoch Time: 1m 54s
# 	Train Loss: 0.152 | Train Acc: 94.04%
# 	 Val. Loss: 0.370 |  Val. Acc: 84.99%
# Epoch: 66 | Epoch Time: 1m 54s
# 	Train Loss: 0.152 | Train Acc: 94.03%
# 	 Val. Loss: 0.372 |  Val. Acc: 84.82%
# Epoch: 67 | Epoch Time: 1m 55s
# 	Train Loss: 0.151 | Train Acc: 94.06%
# 	 Val. Loss: 0.375 |  Val. Acc: 84.66%
# Epoch: 68 | Epoch Time: 1m 54s
# 	Train Loss: 0.151 | Train Acc: 94.08%
# 	 Val. Loss: 0.375 |  Val. Acc: 84.60%
# Epoch: 69 | Epoch Time: 1m 54s
# 	Train Loss: 0.151 | Train Acc: 94.09%
# 	 Val. Loss: 0.378 |  Val. Acc: 84.47%
# Epoch: 70 | Epoch Time: 1m 54s
# 	Train Loss: 0.150 | Train Acc: 94.06%
# 	 Val. Loss: 0.381 |  Val. Acc: 84.38%
# Epoch: 71 | Epoch Time: 1m 55s
# 	Train Loss: 0.149 | Train Acc: 94.13%
# 	 Val. Loss: 0.371 |  Val. Acc: 84.97%
# Epoch: 72 | Epoch Time: 1m 55s
# 	Train Loss: 0.149 | Train Acc: 94.15%
# 	 Val. Loss: 0.375 |  Val. Acc: 84.75%
# Epoch: 73 | Epoch Time: 1m 55s
# 	Train Loss: 0.148 | Train Acc: 94.23%
# 	 Val. Loss: 0.371 |  Val. Acc: 84.90%
# Epoch: 74 | Epoch Time: 1m 55s
# 	Train Loss: 0.147 | Train Acc: 94.23%
# 	 Val. Loss: 0.377 |  Val. Acc: 84.59%
# Epoch: 75 | Epoch Time: 1m 55s
# 	Train Loss: 0.147 | Train Acc: 94.24%
# 	 Val. Loss: 0.368 |  Val. Acc: 85.07%
# Epoch: 76 | Epoch Time: 1m 53s
# 	Train Loss: 0.146 | Train Acc: 94.27%
# 	 Val. Loss: 0.371 |  Val. Acc: 84.92%
# Epoch: 77 | Epoch Time: 1m 53s
# 	Train Loss: 0.145 | Train Acc: 94.30%
# 	 Val. Loss: 0.380 |  Val. Acc: 84.54%
# Epoch: 78 | Epoch Time: 1m 51s
# 	Train Loss: 0.145 | Train Acc: 94.32%
# 	 Val. Loss: 0.376 |  Val. Acc: 84.74%
# Epoch: 79 | Epoch Time: 1m 53s
# 	Train Loss: 0.144 | Train Acc: 94.34%
# 	 Val. Loss: 0.360 |  Val. Acc: 85.36%
# Epoch: 80 | Epoch Time: 1m 52s
# 	Train Loss: 0.144 | Train Acc: 94.36%
# 	 Val. Loss: 0.372 |  Val. Acc: 84.83%

# %% [markdown]
# **Load the parameters of the best model**

# %%
model.load_state_dict(torch.load('smote_v3.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### **Examining the Model**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, balanced_accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# **Visualizing loss of train set and valid set**

# %%
epoch_list = np.arange(1, EPOCHS + 1)

# %%
fig, ax = plt.subplots(figsize=(14,8))

ax.plot(epoch_list, train_loss_list, label='train loss')
ax.plot(epoch_list, valid_loss_list, label='validate loss')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')

ax.legend()
plt.show()

# %% [markdown]
# **Get the predictions**

# %%
def get_predictions(model, X, y, device, batch_size):
    
    model.eval()
    y_predict = []

    with torch.no_grad():
        for (batchX, batchY) in next_batch(X, y, batch_size):
            X = torch.from_numpy(batchX).to(device)

            y_tmp = model(X)
            top_pred = y_tmp.argmax(1, keepdim = True)

            for i in top_pred:
                y_predict.append(i.item())

    return np.array(y_predict)

# %%
y_predict = get_predictions(model, X_test, y_test, device, batch_size=BATCH_SIZE)

# %% [markdown]
# **Confusion matrix**

# %%
cm = confusion_matrix(y_test, y_predict)
print(cm)
# Out:
# [[34369  5059]
#  [ 2791 12826]]

# %%
pd_cm = pd.DataFrame(cm, index = ['negative', 'positive'], columns = ['negative', 'positive'])

# %%
plt.figure(figsize=(14,10))
ax = plt.axes()
sn.heatmap(pd_cm, annot=True, fmt='d', cmap='Blues')
ax.set_xlabel('Predict label')
ax.set_ylabel('True label')

plt.show()

# %% [markdown]
# **Quantifying the quality of predictions**

# %%
def show_metrics_scores(y_test, y_predict):
    print(f'Accuracy score\t\t: {accuracy_score(y_test, y_predict):.4f}\n')
    print(f'Balanced accuracy score\t: {balanced_accuracy_score(y_test, y_predict):.4f}\n')
    print(f'F1 score\t\t: {f1_score(y_test, y_predict):.4f}\n')
    print(f'Recall score\t\t: {recall_score(y_test, y_predict):.4f}')

# %%
show_metrics_scores(y_test, y_predict)
# Out:
# Accuracy score		: 0.8574
#
# Balanced accuracy score	: 0.8465
#
# F1 score		: 0.7657
#
# Recall score		: 0.8213
