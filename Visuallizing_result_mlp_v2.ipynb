# %% [markdown]
# **Connect to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/Colab\ Notebooks/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import h5py

# %% [markdown]
# **Load loss**

# %%
def load_loss():
    filename = 'mlp_v2/loss.hdf5'

    with h5py.File(filename, 'r') as f:
        return f['data'][:]

# %% [markdown]
# **Visualizing Loss**

# %%
loss = load_loss()

# %%
loss
# Out:
# array([0.49404805, 0.4738015 , 0.46464142, 0.45521873, 0.43825286,
#        0.43235417, 0.43074313, 0.4280023 , 0.42535643, 0.42131761,
#        0.42053557, 0.4175257 , 0.41723379, 0.41491527, 0.41280135,
#        0.41229825, 0.41186501, 0.41118304, 0.40945223, 0.40728341])

# %%
plt.figure(figsize=(20,5))
plt.plot(loss)
plt.xlabel('epoch')
plt.ylabel('loss')

plt.show()

# %% [markdown]
# **Confusion Matrix**

# %%
cm = [[54541, 7812], [9957, 17444]]

# %%
np_cm = np.array(cm)

# %%
plt.figure(figsize=(14,10))
ax = plt.axes()
sn.heatmap(np_cm, annot=True, fmt='d', cmap='Blues')
ax.set_xlabel('Predict label')
ax.set_ylabel('True label')

plt.show()
